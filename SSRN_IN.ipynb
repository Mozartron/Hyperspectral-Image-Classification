# %%
# !wget -c https://repo.continuum.io/archive/Anaconda2-5.3.1-Linux-x86_64.sh
# !chmod +x Anaconda2-5.3.1-Linux-x86_64.sh
# !bash ./Anaconda2-5.3.1-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2019-05-06 21:22:21--  https://repo.continuum.io/archive/Anaconda2-5.3.1-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 647814227 (618M) [application/x-sh]
# Saving to: ‘Anaconda2-5.3.1-Linux-x86_64.sh’
#
# Anaconda2-5.3.1-Lin 100%[===================>] 617.80M   102MB/s    in 13s
#
# 2019-05-06 21:22:33 (48.4 MB/s) - ‘Anaconda2-5.3.1-Linux-x86_64.sh’ saved [647814227/647814227]
#
# PREFIX=/usr/local
# reinstalling: python-2.7.15-h1571d57_0 ...
# Python 2.7.15 :: Anaconda, Inc.
# reinstalling: blas-1.0-mkl ...
# reinstalling: ca-certificates-2018.03.07-0 ...
# reinstalling: conda-env-2.6.0-1 ...
# reinstalling: intel-openmp-2019.0-118 ...
# reinstalling: libgcc-ng-8.2.0-hdf63c60_1 ...
# reinstalling: libgfortran-ng-7.3.0-hdf63c60_0 ...
# reinstalling: libstdcxx-ng-8.2.0-hdf63c60_1 ...
# reinstalling: bzip2-1.0.6-h14c3975_5 ...
# reinstalling: expat-2.2.6-he6710b0_0 ...
# reinstalling: fribidi-1.0.5-h7b6447c_0 ...
# reinstalling: gmp-6.1.2-h6c8ec71_1 ...
# reinstalling: graphite2-1.3.12-h23475e2_2 ...
# reinstalling: icu-58.2-h9c2bf20_1 ...
# reinstalling: jbig-2.1-hdba287a_0 ...
# reinstalling: jpeg-9b-h024ee3a_2 ...
# reinstalling: libffi-3.2.1-hd88cf55_4 ...
# reinstalling: libsodium-1.0.16-h1bed415_0 ...
# reinstalling: libtool-2.4.6-h544aabb_3 ...
# reinstalling: libuuid-1.0.3-h1bed415_2 ...
# reinstalling: libxcb-1.13-h1bed415_1 ...
# reinstalling: lzo-2.10-h49e0be7_2 ...
# reinstalling: mkl-2019.0-118 ...
# reinstalling: ncurses-6.1-hf484d3e_0 ...
# reinstalling: openssl-1.0.2p-h14c3975_0 ...
# reinstalling: patchelf-0.9-hf484d3e_2 ...
# reinstalling: pcre-8.42-h439df22_0 ...
# reinstalling: pixman-0.34.0-hceecf20_3 ...
# reinstalling: snappy-1.1.7-hbae5bb6_3 ...
# reinstalling: xz-5.2.4-h14c3975_4 ...
# reinstalling: yaml-0.1.7-had09818_2 ...
# reinstalling: zlib-1.2.11-ha838bed_2 ...
# reinstalling: blosc-1.14.4-hdbcaa40_0 ...
# reinstalling: glib-2.56.2-hd408876_0 ...
# reinstalling: hdf5-1.10.2-hba1933b_1 ...
# reinstalling: libedit-3.1.20170329-h6b74fdf_2 ...
# reinstalling: libpng-1.6.34-hb9fc6fc_0 ...
# reinstalling: libssh2-1.8.0-h9cfc8f7_4 ...
# reinstalling: libtiff-4.0.9-he85c1e1_2 ...
# reinstalling: libxml2-2.9.8-h26e45fe_1 ...
# reinstalling: mpfr-4.0.1-hdf1c602_3 ...
# reinstalling: pandoc-1.19.2.1-hea2e7c5_1 ...
# reinstalling: readline-7.0-h7b6447c_5 ...
# reinstalling: tk-8.6.8-hbc83047_0 ...
# reinstalling: zeromq-4.2.5-hf484d3e_1 ...
# reinstalling: dbus-1.13.2-h714fa37_1 ...
# reinstalling: freetype-2.9.1-h8a8886c_1 ...
# reinstalling: gstreamer-1.14.0-hb453b48_1 ...
# reinstalling: libcurl-7.61.0-h1ad7b7a_0 ...
# reinstalling: libxslt-1.1.32-h1312cb7_0 ...
# reinstalling: mpc-1.1.0-h10f8cd9_1 ...
# reinstalling: sqlite-3.24.0-h84994c4_0 ...
# reinstalling: unixodbc-2.3.7-h14c3975_0 ...
# reinstalling: curl-7.61.0-h84994c4_0 ...
# reinstalling: fontconfig-2.13.0-h9420a91_0 ...
# reinstalling: gst-plugins-base-1.14.0-hbbd80ab_1 ...
# reinstalling: alabaster-0.7.11-py27_0 ...
# reinstalling: appdirs-1.4.3-py27h28b3542_0 ...
# reinstalling: asn1crypto-0.24.0-py27_0 ...
# reinstalling: atomicwrites-1.2.1-py27_0 ...
# reinstalling: attrs-18.2.0-py27h28b3542_0 ...
# reinstalling: backports-1.0-py27_1 ...
# reinstalling: backports_abc-0.5-py27_0 ...
# reinstalling: beautifulsoup4-4.6.3-py27_0 ...
# reinstalling: bitarray-0.8.3-py27h14c3975_0 ...
# reinstalling: boto-2.49.0-py27_0 ...
# reinstalling: cairo-1.14.12-h8948797_3 ...
# reinstalling: cdecimal-2.3-py27h14c3975_3 ...
# reinstalling: certifi-2018.8.24-py27_1 ...
# reinstalling: chardet-3.0.4-py27_1 ...
# reinstalling: click-6.7-py27_0 ...
# reinstalling: cloudpickle-0.5.5-py27_0 ...
# reinstalling: colorama-0.3.9-py27_0 ...
# reinstalling: configparser-3.5.0-py27_0 ...
# reinstalling: constantly-15.1.0-py27h28b3542_0 ...
# reinstalling: contextlib2-0.5.5-py27_0 ...
# reinstalling: dask-core-0.19.1-py27_0 ...
# reinstalling: decorator-4.3.0-py27_0 ...
# reinstalling: defusedxml-0.5.0-py27_1 ...
# reinstalling: docutils-0.14-py27_0 ...
# reinstalling: enum34-1.1.6-py27_1 ...
# reinstalling: et_xmlfile-1.0.1-py27_0 ...
# reinstalling: fastcache-1.0.2-py27h14c3975_2 ...
# reinstalling: filelock-3.0.8-py27_0 ...
# reinstalling: funcsigs-1.0.2-py27_0 ...
# reinstalling: functools32-3.2.3.2-py27_1 ...
# reinstalling: futures-3.2.0-py27_0 ...
# reinstalling: glob2-0.6-py27_0 ...
# reinstalling: gmpy2-2.0.8-py27h10f8cd9_2 ...
# reinstalling: greenlet-0.4.15-py27h7b6447c_0 ...
# reinstalling: grin-1.2.1-py27_4 ...
# reinstalling: heapdict-1.0.0-py27_2 ...
# reinstalling: idna-2.7-py27_0 ...
# reinstalling: imagesize-1.1.0-py27_0 ...
# reinstalling: incremental-17.5.0-py27_0 ...
# reinstalling: ipaddress-1.0.22-py27_0 ...
# reinstalling: ipython_genutils-0.2.0-py27_0 ...
# reinstalling: itsdangerous-0.24-py27_1 ...
# reinstalling: jdcal-1.4-py27_0 ...
# reinstalling: kiwisolver-1.0.1-py27hf484d3e_0 ...
# reinstalling: lazy-object-proxy-1.3.1-py27h14c3975_2 ...
# reinstalling: linecache2-1.0.0-py27_0 ...
# reinstalling: locket-0.2.0-py27_1 ...
# reinstalling: lxml-4.2.5-py27hefd8a0e_0 ...
# reinstalling: markupsafe-1.0-py27h14c3975_1 ...
# reinstalling: mccabe-0.6.1-py27_1 ...
# reinstalling: mistune-0.8.3-py27h14c3975_1 ...
# reinstalling: mkl-service-1.1.2-py27h90e4bf4_5 ...
# reinstalling: mpmath-1.0.0-py27_2 ...
# reinstalling: msgpack-python-0.5.6-py27h6bb024c_1 ...
# reinstalling: numpy-base-1.15.1-py27h81de0dd_0 ...
# reinstalling: olefile-0.46-py27_0 ...
# reinstalling: pandocfilters-1.4.2-py27_1 ...
# reinstalling: parso-0.3.1-py27_0 ...
# reinstalling: path.py-11.1.0-py27_0 ...
# reinstalling: pep8-1.7.1-py27_0 ...
# reinstalling: pkginfo-1.4.2-py27_1 ...
# reinstalling: pluggy-0.7.1-py27h28b3542_0 ...
# reinstalling: ply-3.11-py27_0 ...
# reinstalling: psutil-5.4.7-py27h14c3975_0 ...
# reinstalling: ptyprocess-0.6.0-py27_0 ...
# reinstalling: py-1.6.0-py27_0 ...
# reinstalling: pyasn1-0.4.4-py27h28b3542_0 ...
# reinstalling: pycodestyle-2.4.0-py27_0 ...
# reinstalling: pycosat-0.6.3-py27h14c3975_0 ...
# reinstalling: pycparser-2.18-py27_1 ...
# reinstalling: pycrypto-2.6.1-py27h14c3975_9 ...
# reinstalling: pycurl-7.43.0.2-py27hb7f436b_0 ...
# reinstalling: pyflakes-2.0.0-py27_0 ...
# reinstalling: pyodbc-4.0.24-py27he6710b0_0 ...
# reinstalling: pyparsing-2.2.0-py27_1 ...
# reinstalling: pysocks-1.6.8-py27_0 ...
# reinstalling: pytz-2018.5-py27_0 ...
# reinstalling: pyyaml-3.13-py27h14c3975_0 ...
# reinstalling: pyzmq-17.1.2-py27h14c3975_0 ...
# reinstalling: qt-5.9.6-h8703b6f_2 ...
# reinstalling: qtpy-1.5.0-py27_0 ...
# reinstalling: rope-0.11.0-py27_0 ...
# reinstalling: ruamel_yaml-0.15.46-py27h14c3975_0 ...
# reinstalling: scandir-1.9.0-py27h14c3975_0 ...
# reinstalling: send2trash-1.5.0-py27_0 ...
# reinstalling: simplegeneric-0.8.1-py27_2 ...
# reinstalling: sip-4.19.8-py27hf484d3e_0 ...
# reinstalling: six-1.11.0-py27_1 ...
# reinstalling: snowballstemmer-1.2.1-py27_0 ...
# reinstalling: sortedcontainers-2.0.5-py27_0 ...
# reinstalling: sphinxcontrib-1.0-py27_1 ...
# reinstalling: sqlalchemy-1.2.11-py27h7b6447c_0 ...
# reinstalling: subprocess32-3.5.2-py27h14c3975_0 ...
# reinstalling: tblib-1.3.2-py27_0 ...
# reinstalling: toolz-0.9.0-py27_0 ...
# reinstalling: tqdm-4.26.0-py27h28b3542_0 ...
# reinstalling: typing-3.6.6-py27_0 ...
# reinstalling: unicodecsv-0.14.1-py27_0 ...
# reinstalling: wcwidth-0.1.7-py27_0 ...
# reinstalling: webencodings-0.5.1-py27_1 ...
# reinstalling: werkzeug-0.14.1-py27_0 ...
# reinstalling: wrapt-1.10.11-py27h14c3975_2 ...
# reinstalling: xlrd-1.1.0-py27_1 ...
# reinstalling: xlsxwriter-1.1.0-py27_0 ...
# reinstalling: xlwt-1.3.0-py27_0 ...
# reinstalling: zope-1.0-py27_1 ...
# reinstalling: automat-0.7.0-py27_0 ...
# reinstalling: babel-2.6.0-py27_0 ...
# reinstalling: backports.shutil_get_terminal_size-1.0.0-py27_2 ...
# reinstalling: cffi-1.11.5-py27he75722e_1 ...
# reinstalling: cycler-0.10.0-py27_0 ...
# reinstalling: cytoolz-0.9.0.1-py27h14c3975_1 ...
# reinstalling: entrypoints-0.2.3-py27_2 ...
# reinstalling: harfbuzz-1.8.8-hffaf4a1_0 ...
# reinstalling: html5lib-1.0.1-py27_0 ...
# reinstalling: hyperlink-18.0.0-py27_0 ...
# reinstalling: jedi-0.12.1-py27_0 ...
# reinstalling: llvmlite-0.24.0-py27hdbcaa40_0 ...
# reinstalling: more-itertools-4.3.0-py27_0 ...
# reinstalling: multipledispatch-0.6.0-py27_0 ...
# reinstalling: networkx-2.1-py27_0 ...
# reinstalling: nltk-3.3.0-py27_0 ...
# reinstalling: openpyxl-2.5.6-py27_0 ...
# reinstalling: packaging-17.1-py27_0 ...
# reinstalling: partd-0.3.8-py27_0 ...
# reinstalling: pathlib2-2.3.2-py27_0 ...
# reinstalling: pexpect-4.6.0-py27_0 ...
# reinstalling: pillow-5.2.0-py27heded4f4_0 ...
# reinstalling: pyasn1-modules-0.2.2-py27_0 ...
# reinstalling: pycairo-1.17.1-py27h2a1e443_0 ...
# reinstalling: pyqt-5.9.2-py27h05f1152_2 ...
# reinstalling: python-dateutil-2.7.3-py27_0 ...
# reinstalling: qtawesome-0.4.4-py27_0 ...
# reinstalling: setuptools-40.2.0-py27_0 ...
# reinstalling: singledispatch-3.4.0.3-py27_0 ...
# reinstalling: sortedcollections-1.0.1-py27_0 ...
# reinstalling: sphinxcontrib-websupport-1.1.0-py27_1 ...
# reinstalling: ssl_match_hostname-3.5.0.1-py27_2 ...
# reinstalling: sympy-1.2-py27_0 ...
# reinstalling: traceback2-1.4.0-py27_0 ...
# reinstalling: traitlets-4.3.2-py27_0 ...
# reinstalling: zict-0.1.3-py27_0 ...
# reinstalling: backports.functools_lru_cache-1.5-py27_1 ...
# reinstalling: bleach-2.1.4-py27_0 ...
# reinstalling: clyent-1.2.2-py27_1 ...
# reinstalling: cryptography-2.3.1-py27hc365091_0 ...
# reinstalling: cython-0.28.5-py27hf484d3e_0 ...
# reinstalling: get_terminal_size-1.0.0-haa9412d_0 ...
# reinstalling: gevent-1.3.6-py27h7b6447c_0 ...
# reinstalling: isort-4.3.4-py27_0 ...
# reinstalling: jinja2-2.10-py27_0 ...
# reinstalling: jsonschema-2.6.0-py27_0 ...
# reinstalling: jupyter_core-4.4.0-py27_0 ...
# reinstalling: navigator-updater-0.2.1-py27_0 ...
# reinstalling: nose-1.3.7-py27_2 ...
# reinstalling: pango-1.42.4-h049681c_0 ...
# reinstalling: pickleshare-0.7.4-py27_0 ...
# reinstalling: pygments-2.2.0-py27_0 ...
# reinstalling: pytest-3.8.0-py27_0 ...
# reinstalling: testpath-0.3.1-py27_0 ...
# reinstalling: tornado-5.1-py27h14c3975_0 ...
# reinstalling: unittest2-1.1.0-py27_0 ...
# reinstalling: wheel-0.31.1-py27_0 ...
# reinstalling: zope.interface-4.5.0-py27h14c3975_0 ...
# reinstalling: astroid-1.6.5-py27_0 ...
# reinstalling: distributed-1.23.1-py27_0 ...
# reinstalling: flask-1.0.2-py27_1 ...
# reinstalling: jupyter_client-5.2.3-py27_0 ...
# reinstalling: nbformat-4.4.0-py27_0 ...
# reinstalling: pip-10.0.1-py27_0 ...
# reinstalling: prompt_toolkit-1.0.15-py27_0 ...
# reinstalling: pyopenssl-18.0.0-py27_0 ...
# reinstalling: terminado-0.8.1-py27_1 ...
# reinstalling: flask-cors-3.0.6-py27_0 ...
# reinstalling: ipython-5.8.0-py27_0 ...
# reinstalling: nbconvert-5.4.0-py27_1 ...
# reinstalling: pylint-1.9.2-py27_0 ...
# reinstalling: service_identity-17.0.0-py27h28b3542_0 ...
# reinstalling: urllib3-1.23-py27_0 ...
# reinstalling: ipykernel-4.9.0-py27_1 ...
# reinstalling: requests-2.19.1-py27_0 ...
# reinstalling: twisted-18.7.0-py27h14c3975_1 ...
# reinstalling: anaconda-client-1.7.2-py27_0 ...
# reinstalling: jupyter_console-5.2.0-py27_1 ...
# reinstalling: prometheus_client-0.3.1-py27h28b3542_0 ...
# reinstalling: qtconsole-4.4.1-py27_0 ...
# reinstalling: sphinx-1.7.9-py27_0 ...
# reinstalling: spyder-kernels-0.2.6-py27_0 ...
# reinstalling: anaconda-navigator-1.9.2-py27_0 ...
# reinstalling: anaconda-project-0.8.2-py27_0 ...
# reinstalling: notebook-5.6.0-py27_0 ...
# reinstalling: numpydoc-0.8.0-py27_0 ...
# reinstalling: jupyterlab_launcher-0.11.2-py27h28b3542_0 ...
# reinstalling: spyder-3.3.1-py27_1 ...
# reinstalling: widgetsnbextension-3.4.1-py27_0 ...
# reinstalling: ipywidgets-7.4.1-py27_0 ...
# reinstalling: jupyterlab-0.33.11-py27_0 ...
# reinstalling: _ipyw_jlab_nb_ext_conf-0.1.0-py27_0 ...
# reinstalling: jupyter-1.0.0-py27_7 ...
# reinstalling: astropy-2.0.8-py27h035aef0_0 ...
# reinstalling: bokeh-0.13.0-py27_0 ...
# reinstalling: bottleneck-1.2.1-py27h035aef0_1 ...
# reinstalling: conda-4.5.11-py27_0 ...
# reinstalling: conda-build-3.15.1-py27_0 ...
# reinstalling: datashape-0.5.4-py27_1 ...
# reinstalling: h5py-2.8.0-py27h989c5e5_3 ...
# reinstalling: imageio-2.4.1-py27_0 ...
# reinstalling: matplotlib-2.2.3-py27hb69df0a_0 ...
# reinstalling: mkl_fft-1.0.4-py27h4414c95_1 ...
# reinstalling: mkl_random-1.0.1-py27h4414c95_1 ...
# reinstalling: numpy-1.15.1-py27h1d66e8a_0 ...
# reinstalling: numba-0.39.0-py27h04863e7_0 ...
# reinstalling: numexpr-2.6.8-py27hd89afb7_0 ...
# reinstalling: pandas-0.23.4-py27h04863e7_0 ...
# reinstalling: pywavelets-1.0.0-py27hdd07704_0 ...
# reinstalling: scipy-1.1.0-py27hfa4b5c9_1 ...
# reinstalling: bkcharts-0.2-py27_0 ...
# reinstalling: dask-0.19.1-py27_0 ...
# reinstalling: patsy-0.5.0-py27_0 ...
# reinstalling: pytables-3.4.4-py27ha205bf6_0 ...
# reinstalling: scikit-image-0.14.0-py27hf484d3e_1 ...
# reinstalling: scikit-learn-0.19.2-py27h4989274_0 ...
# reinstalling: odo-0.5.1-py27_0 ...
# reinstalling: statsmodels-0.9.0-py27h035aef0_0 ...
# reinstalling: blaze-0.11.3-py27_0 ...
# reinstalling: seaborn-0.9.0-py27_0 ...
# reinstalling: anaconda-5.3.1-py27_0 ...
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Anaconda2.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Anaconda2: /usr/local

# %%
from google.colab import drive
drive.mount('/content/drive/')
# !conda install --yes --file /content/drive/My\ Drive/Residual_HSI-Colab/SSRN/package-list.txt
#!ls "/content/drive/My Drive/"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.6.14
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _license==1.1=py27_1
#     - alabaster==0.7.10=py27_0
#     - anaconda-client==1.6.3=py27_0
#     - anaconda-navigator==1.6.2=py27_0
#     - anaconda-project==0.6.0=py27_0
#     - anaconda==custom=py27_0
#     - asn1crypto==0.22.0=py27_0
#     - astroid==1.4.9=py27_0
#     - astropy==1.3.2=np112py27_0
#     - babel==2.4.0=py27_0
#     - backports==1.0=py27_0
#     - backports_abc==0.5=py27_0
#     - beautifulsoup4==4.6.0=py27_0
#     - bitarray==0.8.1=py27_0
#     - blaze==0.10.1=py27_0
#     - bleach==1.5.0=py27_0
#     - bokeh==0.12.5=py27_1
#     - boto==2.46.1=py27_0
#     - bottleneck==1.2.1=np112py27_0
#     - cairo==1.14.8=0
#     - cdecimal==2.3=py27_2
#     - cffi==1.10.0=py27_0
#     - chardet==3.0.3=py27_0
#     - click==6.7=py27_0
#     - cloudpickle==0.2.2=py27_0
#     - clyent==1.2.2=py27_0
#     - colorama==0.3.9=py27_0
#     - conda-env==2.6.0=0
#     - conda==4.3.27=py27hff99c7a_0
#     - configparser==3.5.0=py27_0
#     - contextlib2==0.5.5=py27_0
#     - cryptography==1.8.1=py27_0
#     - curl==7.52.1=0
#     - cycler==0.10.0=py27_0
#     - cython==0.25.2=py27_0
#     - cytoolz==0.8.2=py27_0
#     - dask==0.14.3=py27_1
#     - datashape==0.5.4=py27_0
#     - dbus==1.10.10=0
#     - decorator==4.0.11=py27_0
#     - distributed==1.16.3=py27_0
#     - docutils==0.13.1=py27_0
#     - entrypoints==0.2.2=py27_1
#     - enum34==1.1.6=py27_0
#     - et_xmlfile==1.0.1=py27_0
#     - expat==2.1.0=0
#     - fastcache==1.0.2=py27_1
#     - flask-cors==3.0.2=py27_0
#     - flask==0.12.2=py27_0
#     - fontconfig==2.12.1=3
#     - freetype==2.5.5=2
#     - funcsigs==1.0.2=py27_0
#     - functools32==3.2.3.2=py27_0
#     - futures==3.1.1=py27_0
#     - get_terminal_size==1.0.0=py27_0
#     - gevent==1.2.1=py27_0
#     - glib==2.50.2=1
#     - greenlet==0.4.12=py27_0
#     - grin==1.2.1=py27_3
#     - gst-plugins-base==1.8.0=0
#     - gstreamer==1.8.0=0
#     - h5py==2.7.0=np112py27_0
#     - harfbuzz==0.9.39=2
#     - hdf5==1.8.17=1
#     - heapdict==1.0.0=py27_1
#     - html5lib==0.999=py27_0
#     - icu==54.1=0
#     - idna==2.5=py27_0
#     - imagesize==0.7.1=py27_0
#     - ipaddress==1.0.18=py27_0
#     - ipykernel==4.6.1=py27_0
#     - ipython==5.3.0=py27_0
#     - ipython_genutils==0.2.0=py27_0
#     - ipywidgets==6.0.0=py27_0
#     - isort==4.2.5=py27_0
#     - itsdangerous==0.24=py27_0
#     - jbig==2.1=0
#     - jdcal==1.3=py27_0
#     - jedi==0.10.2=py27_2
#     - jinja2==2.9.6=py27_0
#     - jpeg==9b=0
#     - jsonschema==2.6.0=py27_0
#     - jupyter==1.0.0=py27_3
#     - jupyter_client==5.0.1=py27_0
#     - jupyter_console==5.1.0=py27_0
#     - jupyter_core==4.3.0=py27_0
#     - lazy-object-proxy==1.2.2=py27_0
#     - libffi==3.2.1=1
#     - libgcc==5.2.0=0
#     - libgfortran==3.0.0=1
#     - libiconv==1.14=0
#     - libpng==1.6.27=0
#     - libsodium==1.0.10=0
#     - libtiff==4.0.6=3
#     - libtool==2.4.2=0
#     - libxcb==1.12=1
#     - libxml2==2.9.4=0
#     - libxslt==1.1.29=0
#     - llvmlite==0.18.0=py27_0
#     - locket==0.2.0=py27_1
#     - lxml==3.7.3=py27_0
#     - markupsafe==0.23=py27_2
#     - matplotlib==2.0.2=np112py27_0
#     - mistune==0.7.4=py27_0
#     - mkl-service==1.1.2=py27_3
#     - mkl==2017.0.1=0
#     - mpmath==0.19=py27_1
#     - msgpack-python==0.4.8=py27_0
#     - multipledispatch==0.4.9=py27_0
#     - navigator-updater==0.1.0=py27_0
#     - nbconvert==5.1.1=py27_0
#     - nbformat==4.3.0=py27_0
#     - networkx==1.11=py27_0
#     - nltk==3.2.3=py27_0
#     - nose==1.3.7=py27_1
#     - notebook==5.0.0=py27_0
#     - numba==0.33.0=np112py27_0
#     - numexpr==2.6.2=np112py27_0
#     - numpy==1.12.1=py27_0
#     - numpydoc==0.6.0=py27_0
#     - odo==0.5.0=py27_1
#     - olefile==0.44=py27_0
#     - openpyxl==2.4.7=py27_0
#     - openssl==1.0.2l=0
#     - packaging==16.8=py27_0
#     - pandas==0.20.1=np112py27_0
#     - pandocfilters==1.4.1=py27_0
#     - pango==1.40.3=1
#     - partd==0.3.8=py27_0
#     - path.py==10.3.1=py27_0
#     - pathlib2==2.2.1=py27_0
#     - patsy==0.4.1=py27_0
#     - pcre==8.39=1
#     - pep8==1.7.0=py27_0
#     - pexpect==4.2.1=py27_0
#     - pickleshare==0.7.4=py27_0
#     - pillow==4.1.1=py27_0
#     - pip==9.0.1=py27_1
#     - pixman==0.34.0=0
#     - ply==3.10=py27_0
#     - prompt_toolkit==1.0.14=py27_0
#     - psutil==5.2.2=py27_0
#     - ptyprocess==0.5.1=py27_0
#     - py==1.4.33=py27_0
#     - pycairo==1.10.0=py27_0
#     - pycosat==0.6.2=py27_0
#     - pycparser==2.17=py27_0
#     - pycrypto==2.6.1=py27_6
#     - pycurl==7.43.0=py27_2
#     - pyflakes==1.5.0=py27_0
#     - pygments==2.2.0=py27_0
#     - pylint==1.6.4=py27_1
#     - pyodbc==4.0.16=py27_0
#     - pyopenssl==17.0.0=py27_0
#     - pyparsing==2.1.4=py27_0
#     - pyqt==5.6.0=py27_2
#     - pytables==3.3.0=np112py27_0
#     - pytest==3.0.7=py27_0
#     - python-dateutil==2.6.0=py27_0
#     - python==2.7.13=0
#     - pytz==2017.2=py27_0
#     - pywavelets==0.5.2=np112py27_0
#     - pyyaml==3.12=py27_0
#     - pyzmq==16.0.2=py27_0
#     - qt==5.6.2=4
#     - qtawesome==0.4.4=py27_0
#     - qtconsole==4.3.0=py27_0
#     - qtpy==1.2.1=py27_0
#     - readline==6.2=2
#     - requests==2.14.2=py27_0
#     - rope==0.9.4=py27_1
#     - ruamel_yaml==0.11.14=py27_1
#     - scandir==1.5=py27_0
#     - scikit-image==0.13.0=np112py27_0
#     - scikit-learn==0.18.1=np112py27_1
#     - scipy==0.19.0=np112py27_0
#     - seaborn==0.7.1=py27_0
#     - setuptools==27.2.0=py27_0
#     - simplegeneric==0.8.1=py27_1
#     - singledispatch==3.4.0.3=py27_0
#     - sip==4.18=py27_0
#     - six==1.10.0=py27_0
#     - snowballstemmer==1.2.1=py27_0
#     - sortedcollections==0.5.3=py27_0
#     - sortedcontainers==1.5.7=py27_0
#     - sphinx==1.5.6=py27_0
#     - spyder==3.1.4=py27_0
#     - sqlalchemy==1.1.9=py27_0
#     - sqlite==3.13.0=0
#     - ssl_match_hostname==3.4.0.2=py27_1
#     - statsmodels==0.8.0=np112py27_0
#     - subprocess32==3.2.7=py27_0
#     - sympy==1.0=py27_0
#     - tblib==1.3.2=py27_0
#     - terminado==0.6=py27_0
#     - testpath==0.3=py27_0
#     - tk==8.5.18=0
#     - toolz==0.8.2=py27_0
#     - tornado==4.5.1=py27_0
#     - traitlets==4.3.2=py27_0
#     - unicodecsv==0.14.1=py27_0
#     - unixodbc==2.3.4=0
#     - wcwidth==0.1.7=py27_0
#     - werkzeug==0.12.2=py27_0
#     - wheel==0.29.0=py27_0
#     - widgetsnbextension==2.0.0=py27_0
#     - wrapt==1.10.10=py27_0
#     - xlrd==1.0.0=py27_0
#     - xlsxwriter==0.9.6=py27_0
#     - xlwt==1.2.0=py27_0
#     - xz==5.2.2=1
#     - yaml==0.1.6=0
#     - zeromq==4.1.5=0
#     - zict==0.1.2=py27_0
#     - zlib==1.2.8=3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ptyprocess-0.5.1           |           py27_0          19 KB
#     pycurl-7.43.0              |           py27_2         132 KB
#     cffi-1.10.0                |           py27_0         329 KB
#     pylint-1.6.4               |           py27_1         316 KB
#     yaml-0.1.6                 |                0         246 KB
#     ruamel_yaml-0.11.14        |           py27_1         361 KB
#     openssl-1.0.2l             |                0         3.2 MB
#     clyent-1.2.2               |           py27_0          15 KB
#     pango-1.40.3               |                1         938 KB
#     sortedcontainers-1.5.7     |           py27_0          44 KB
#     pcre-8.39                  |                1         656 KB
#     ipython-5.3.0              |           py27_0         974 KB
#     gst-plugins-base-1.8.0     |                0         3.1 MB
#     ipykernel-4.6.1            |           py27_0         135 KB
#     prompt_toolkit-1.0.14      |           py27_0         330 KB
#     cytoolz-0.8.2              |           py27_0         913 KB
#     hdf5-1.8.17                |                1         1.9 MB
#     freetype-2.5.5             |                2         2.5 MB
#     jupyter_core-4.3.0         |           py27_0          59 KB
#     bleach-1.5.0               |           py27_0          21 KB
#     libgfortran-3.0.0          |                1         281 KB
#     imagesize-0.7.1            |           py27_0           3 KB
#     widgetsnbextension-2.0.0   |           py27_0         878 KB
#     libiconv-1.14              |                0         2.0 MB
#     pyflakes-1.5.0             |           py27_0          80 KB
#     icu-54.1                   |                0        11.3 MB
#     zlib-1.2.8                 |                3         101 KB
#     odo-0.5.0                  |           py27_1         175 KB
#     jpeg-9b                    |                0         941 KB
#     pyparsing-2.1.4            |           py27_0          70 KB
#     pep8-1.7.0                 |           py27_0          47 KB
#     numexpr-2.6.2              |      np112py27_0         353 KB
#     libffi-3.2.1               |                1          38 KB
#     wrapt-1.10.10              |           py27_0          64 KB
#     scandir-1.5                |           py27_0          40 KB
#     requests-2.14.2            |           py27_0         700 KB
#     anaconda-custom            |           py27_0           3 KB
#     xlwt-1.2.0                 |           py27_0         160 KB
#     notebook-5.0.0             |           py27_0         5.3 MB
#     seaborn-0.7.1              |           py27_0         272 KB
#     anaconda-navigator-1.6.2   |           py27_0         3.8 MB
#     python-2.7.13              |                0        11.5 MB
#     pycairo-1.10.0             |           py27_0          81 KB
#     tk-8.5.18                  |                0         1.9 MB
#     libxslt-1.1.29             |                0         983 KB
#     greenlet-0.4.12            |           py27_0          37 KB
#     patsy-0.4.1                |           py27_0         325 KB
#     libtool-2.4.2              |                0         547 KB
#     py-1.4.33                  |           py27_0         130 KB
#     _license-1.1               |           py27_1         271 KB
#     six-1.10.0                 |           py27_0          16 KB
#     jinja2-2.9.6               |           py27_0         348 KB
#     html5lib-0.999             |           py27_0         172 KB
#     docutils-0.13.1            |           py27_0         679 KB
#     pillow-4.1.1               |           py27_0         840 KB
#     anaconda-client-1.6.3      |           py27_0         129 KB
#     libpng-1.6.27              |                0         219 KB
#     ssl_match_hostname-3.4.0.2 |           py27_1           6 KB
#     sqlite-3.13.0              |                0         4.0 MB
#     toolz-0.8.2                |           py27_0          89 KB
#     jupyter-1.0.0              |           py27_3           3 KB
#     boto-2.46.1                |           py27_0         1.4 MB
#     libxcb-1.12                |                1         1.5 MB
#     mkl-service-1.1.2          |           py27_3          15 KB
#     jupyter_console-5.1.0      |           py27_0          33 KB
#     psutil-5.2.2               |           py27_0         260 KB
#     lazy-object-proxy-1.2.2    |           py27_0          53 KB
#     pathlib2-2.2.1             |           py27_0          30 KB
#     idna-2.5                   |           py27_0         121 KB
#     sqlalchemy-1.1.9           |           py27_0         1.4 MB
#     babel-2.4.0                |           py27_0         4.9 MB
#     sphinx-1.5.6               |           py27_0         1.3 MB
#     blaze-0.10.1               |           py27_0         577 KB
#     zict-0.1.2                 |           py27_0          17 KB
#     libsodium-1.0.10           |                0         1.2 MB
#     bokeh-0.12.5               |           py27_1         4.1 MB
#     pytz-2017.2                |           py27_0         204 KB
#     certifi-2019.3.9           |           py27_0         155 KB
#     cryptography-1.8.1         |           py27_0         850 KB
#     astroid-1.4.9              |           py27_0         251 KB
#     pexpect-4.2.1              |           py27_0          69 KB
#     gevent-1.2.1               |           py27_0         1.3 MB
#     astropy-1.3.2              |      np112py27_0         8.8 MB
#     gstreamer-1.8.0            |                0         2.6 MB
#     cython-0.25.2              |           py27_0         5.6 MB
#     chardet-3.0.3              |           py27_0         175 KB
#     setuptools-27.2.0          |           py27_0         521 KB
#     matplotlib-2.0.2           |      np112py27_0        10.6 MB
#     nltk-3.2.3                 |           py27_0         1.8 MB
#     pyqt-5.6.0                 |           py27_2         5.3 MB
#     libxml2-2.9.4              |                0         3.7 MB
#     dask-0.14.3                |           py27_1         812 KB
#     curl-7.52.1                |                0         558 KB
#     grin-1.2.1                 |           py27_3          24 KB
#     scipy-0.19.0               |      np112py27_0        35.3 MB
#     python-dateutil-2.6.0      |           py27_0         232 KB
#     unixodbc-2.3.4             |                0         688 KB
#     zeromq-4.1.5               |                0         4.1 MB
#     scikit-learn-0.18.1        |      np112py27_1        11.0 MB
#     get_terminal_size-1.0.0    |           py27_0           4 KB
#     enum34-1.1.6               |           py27_0          53 KB
#     entrypoints-0.2.2          |           py27_1           9 KB
#     packaging-16.8             |           py27_0          30 KB
#     bitarray-0.8.1             |           py27_0          89 KB
#     terminado-0.6              |           py27_0          18 KB
#     pycrypto-2.6.1             |           py27_6         459 KB
#     anaconda-project-0.6.0     |           py27_0         208 KB
#     openpyxl-2.4.7             |           py27_0         285 KB
#     ply-3.10                   |           py27_0          75 KB
#     xz-5.2.2                   |                1         669 KB
#     rope-0.9.4                 |           py27_1         225 KB
#     lxml-3.7.3                 |           py27_0         2.9 MB
#     networkx-1.11              |           py27_0         1.1 MB
#     bottleneck-1.2.1           |      np112py27_0         304 KB
#     jbig-2.1                   |                0          29 KB
#     isort-4.2.5                |           py27_0          51 KB
#     pywavelets-0.5.2           |      np112py27_0         5.1 MB
#     statsmodels-0.8.0          |      np112py27_0         7.3 MB
#     glib-2.50.2                |                1         5.6 MB
#     numba-0.33.0               |      np112py27_0         2.2 MB
#     h5py-2.7.0                 |      np112py27_0         2.5 MB
#     msgpack-python-0.4.8       |           py27_0         209 KB
#     backports-1.0              |           py27_0           1 KB
#     cairo-1.14.8               |                0         609 KB
#     libgcc-5.2.0               |                0         1.1 MB
#     futures-3.1.1              |           py27_0          22 KB
#     fastcache-1.0.2            |           py27_1          41 KB
#     sip-4.18                   |           py27_0         264 KB
#     olefile-0.44               |           py27_0          52 KB
#     subprocess32-3.2.7         |           py27_0          55 KB
#     pycosat-0.6.2              |           py27_0         194 KB
#     asn1crypto-0.22.0          |           py27_0         145 KB
#     werkzeug-0.12.2            |           py27_0         408 KB
#     sortedcollections-0.5.3    |           py27_0          13 KB
#     mistune-0.7.4              |           py27_0         605 KB
#     harfbuzz-0.9.39            |                2         1.2 MB
#     fontconfig-2.12.1          |                3         429 KB
#     dbus-1.10.10               |                0         2.4 MB
#     pandas-0.20.1              |      np112py27_0        19.2 MB
#     pyyaml-3.12                |           py27_0         313 KB
#     alabaster-0.7.10           |           py27_0          14 KB
#     sympy-1.0                  |           py27_0         5.6 MB
#     simplegeneric-0.8.1        |           py27_1           7 KB
#     libssh2-1.8.0              |       h8c220ad_2         243 KB
#     blosc-1.2.3                |                0          18 KB
#     markupsafe-0.23            |           py27_2          31 KB
#     flask-0.12.2               |           py27_0         102 KB
#     conda-4.3.27               |   py27hff99c7a_0         508 KB
#     wheel-0.29.0               |           py27_0          81 KB
#     xlrd-1.0.0                 |           py27_0         181 KB
#     jdcal-1.3                  |           py27_0           8 KB
#     spyder-kernels-1.3.2       |           py27_0          63 KB
#     pixman-0.34.0              |                0         3.8 MB
#     testpath-0.3               |           py27_0          15 KB
#     scikit-image-0.13.0        |      np112py27_0        31.6 MB
#     pandocfilters-1.4.1        |           py27_0          12 KB
#     ipywidgets-6.0.0           |           py27_0          63 KB
#     itsdangerous-0.24          |           py27_0          16 KB
#     functools32-3.2.3.2        |           py27_0          15 KB
#     qt-5.6.2                   |                4        43.4 MB
#     numpydoc-0.6.0             |           py27_0          57 KB
#     navigator-updater-0.1.0    |           py27_0         1.2 MB
#     path.py-10.3.1             |           py27_0          48 KB
#     qtpy-1.2.1                 |           py27_0          28 KB
#     pytables-3.3.0             |      np112py27_0         5.5 MB
#     numpy-1.12.1               |           py27_0         6.6 MB
#     multipledispatch-0.4.9     |           py27_0          12 KB
#     pyzmq-16.0.2               |           py27_0         835 KB
#     heapdict-1.0.0             |           py27_1           5 KB
#     expat-2.1.0                |                0         365 KB
#     xlsxwriter-0.9.6           |           py27_0         198 KB
#     pyodbc-4.0.16              |           py27_0         168 KB
#     ipaddress-1.0.18           |           py27_0          31 KB
#     readline-6.2               |                2         606 KB
#     cdecimal-2.3               |           py27_2         439 KB
#     beautifulsoup4-4.6.0       |           py27_0         129 KB
#     distributed-1.16.3         |           py27_0         551 KB
#     libtiff-4.0.6              |                3         1.5 MB
#     tornado-4.5.1              |           py27_0         592 KB
#     datashape-0.5.4            |           py27_0          96 KB
#     ca-certificates-2019.1.23  |                0         126 KB
#     nbconvert-5.1.1            |           py27_0         355 KB
#     pyopenssl-17.0.0           |           py27_0          74 KB
#     flask-cors-3.0.2           |           py27_0          20 KB
#     spyder-3.1.4               |           py27_0         3.1 MB
#     nbformat-4.3.0             |           py27_0         133 KB
#     jupyter_client-5.0.1       |           py27_0         112 KB
#     mpmath-0.19                |           py27_1         873 KB
#     mkl-2017.0.1               |                0       128.2 MB
#     cloudpickle-0.2.2          |           py27_0          20 KB
#     qtconsole-4.3.0            |           py27_0         173 KB
#     pip-9.0.1                  |           py27_1         1.6 MB
#     decorator-4.0.11           |           py27_0          15 KB
#     pytest-3.0.7               |           py27_0         258 KB
#     pycparser-2.17             |           py27_0         153 KB
#     conda-env-2.6.0            |                0          502 B
#     llvmlite-0.18.0            |           py27_0        11.2 MB
#     jedi-0.10.2                |           py27_2         242 KB
#     nose-1.3.7                 |           py27_1         194 KB
#     ------------------------------------------------------------
#                                            Total:       483.8 MB
#
# The following NEW packages will be INSTALLED:
#
#     _license:           1.1-py27_1
#     libgcc:             5.2.0-0
#     libgfortran:        3.0.0-1
#     libiconv:           1.14-0
#
# The following packages will be REMOVED:
#
#     libcurl:            7.61.0-h1ad7b7a_0
#
# The following packages will be UPDATED:
#
#     anaconda:           5.3.1-py27_0            --> custom-py27_0
#     ca-certificates:    2018.03.07-0            --> 2019.1.23-0
#     certifi:            2018.8.24-py27_1        --> 2019.3.9-py27_0
#     get_terminal_size:  1.0.0-haa9412d_0        --> 1.0.0-py27_0
#     jbig:               2.1-hdba287a_0          --> 2.1-0
#     spyder-kernels:     0.2.6-py27_0            --> 1.3.2-py27_0
#
# The following packages will be DOWNGRADED:
#
#     alabaster:          0.7.11-py27_0           --> 0.7.10-py27_0
#     anaconda-client:    1.7.2-py27_0            --> 1.6.3-py27_0
#     anaconda-navigator: 1.9.2-py27_0            --> 1.6.2-py27_0
#     anaconda-project:   0.8.2-py27_0            --> 0.6.0-py27_0
#     asn1crypto:         0.24.0-py27_0           --> 0.22.0-py27_0
#     astroid:            1.6.5-py27_0            --> 1.4.9-py27_0
#     astropy:            2.0.8-py27h035aef0_0    --> 1.3.2-np112py27_0
#     babel:              2.6.0-py27_0            --> 2.4.0-py27_0
#     backports:          1.0-py27_1              --> 1.0-py27_0
#     beautifulsoup4:     4.6.3-py27_0            --> 4.6.0-py27_0
#     bitarray:           0.8.3-py27h14c3975_0    --> 0.8.1-py27_0
#     blaze:              0.11.3-py27_0           --> 0.10.1-py27_0
#     bleach:             2.1.4-py27_0            --> 1.5.0-py27_0
#     blosc:              1.14.4-hdbcaa40_0       --> 1.2.3-0
#     bokeh:              0.13.0-py27_0           --> 0.12.5-py27_1
#     boto:               2.49.0-py27_0           --> 2.46.1-py27_0
#     bottleneck:         1.2.1-py27h035aef0_1    --> 1.2.1-np112py27_0
#     cairo:              1.14.12-h8948797_3      --> 1.14.8-0
#     cdecimal:           2.3-py27h14c3975_3      --> 2.3-py27_2
#     cffi:               1.11.5-py27he75722e_1   --> 1.10.0-py27_0
#     chardet:            3.0.4-py27_1            --> 3.0.3-py27_0
#     cloudpickle:        0.5.5-py27_0            --> 0.2.2-py27_0
#     clyent:             1.2.2-py27_1            --> 1.2.2-py27_0
#     conda:              4.5.11-py27_0           --> 4.3.27-py27hff99c7a_0
#     conda-env:          2.6.0-1                 --> 2.6.0-0
#     cryptography:       2.3.1-py27hc365091_0    --> 1.8.1-py27_0
#     curl:               7.61.0-h84994c4_0       --> 7.52.1-0
#     cython:             0.28.5-py27hf484d3e_0   --> 0.25.2-py27_0
#     cytoolz:            0.9.0.1-py27h14c3975_1  --> 0.8.2-py27_0
#     dask:               0.19.1-py27_0           --> 0.14.3-py27_1
#     datashape:          0.5.4-py27_1            --> 0.5.4-py27_0
#     dbus:               1.13.2-h714fa37_1       --> 1.10.10-0
#     decorator:          4.3.0-py27_0            --> 4.0.11-py27_0
#     distributed:        1.23.1-py27_0           --> 1.16.3-py27_0
#     docutils:           0.14-py27_0             --> 0.13.1-py27_0
#     entrypoints:        0.2.3-py27_2            --> 0.2.2-py27_1
#     enum34:             1.1.6-py27_1            --> 1.1.6-py27_0
#     expat:              2.2.6-he6710b0_0        --> 2.1.0-0
#     fastcache:          1.0.2-py27h14c3975_2    --> 1.0.2-py27_1
#     flask:              1.0.2-py27_1            --> 0.12.2-py27_0
#     flask-cors:         3.0.6-py27_0            --> 3.0.2-py27_0
#     fontconfig:         2.13.0-h9420a91_0       --> 2.12.1-3
#     freetype:           2.9.1-h8a8886c_1        --> 2.5.5-2
#     functools32:        3.2.3.2-py27_1          --> 3.2.3.2-py27_0
#     futures:            3.2.0-py27_0            --> 3.1.1-py27_0
#     gevent:             1.3.6-py27h7b6447c_0    --> 1.2.1-py27_0
#     glib:               2.56.2-hd408876_0       --> 2.50.2-1
#     greenlet:           0.4.15-py27h7b6447c_0   --> 0.4.12-py27_0
#     grin:               1.2.1-py27_4            --> 1.2.1-py27_3
#     gst-plugins-base:   1.14.0-hbbd80ab_1       --> 1.8.0-0
#     gstreamer:          1.14.0-hb453b48_1       --> 1.8.0-0
#     h5py:               2.8.0-py27h989c5e5_3    --> 2.7.0-np112py27_0
#     harfbuzz:           1.8.8-hffaf4a1_0        --> 0.9.39-2
#     hdf5:               1.10.2-hba1933b_1       --> 1.8.17-1
#     heapdict:           1.0.0-py27_2            --> 1.0.0-py27_1
#     html5lib:           1.0.1-py27_0            --> 0.999-py27_0
#     icu:                58.2-h9c2bf20_1         --> 54.1-0
#     idna:               2.7-py27_0              --> 2.5-py27_0
#     imagesize:          1.1.0-py27_0            --> 0.7.1-py27_0
#     ipaddress:          1.0.22-py27_0           --> 1.0.18-py27_0
#     ipykernel:          4.9.0-py27_1            --> 4.6.1-py27_0
#     ipython:            5.8.0-py27_0            --> 5.3.0-py27_0
#     ipywidgets:         7.4.1-py27_0            --> 6.0.0-py27_0
#     isort:              4.3.4-py27_0            --> 4.2.5-py27_0
#     itsdangerous:       0.24-py27_1             --> 0.24-py27_0
#     jdcal:              1.4-py27_0              --> 1.3-py27_0
#     jedi:               0.12.1-py27_0           --> 0.10.2-py27_2
#     jinja2:             2.10-py27_0             --> 2.9.6-py27_0
#     jpeg:               9b-h024ee3a_2           --> 9b-0
#     jupyter:            1.0.0-py27_7            --> 1.0.0-py27_3
#     jupyter_client:     5.2.3-py27_0            --> 5.0.1-py27_0
#     jupyter_console:    5.2.0-py27_1            --> 5.1.0-py27_0
#     jupyter_core:       4.4.0-py27_0            --> 4.3.0-py27_0
#     lazy-object-proxy:  1.3.1-py27h14c3975_2    --> 1.2.2-py27_0
#     libffi:             3.2.1-hd88cf55_4        --> 3.2.1-1
#     libpng:             1.6.34-hb9fc6fc_0       --> 1.6.27-0
#     libsodium:          1.0.16-h1bed415_0       --> 1.0.10-0
#     libssh2:            1.8.0-h9cfc8f7_4        --> 1.8.0-h8c220ad_2
#     libtiff:            4.0.9-he85c1e1_2        --> 4.0.6-3
#     libtool:            2.4.6-h544aabb_3        --> 2.4.2-0
#     libxcb:             1.13-h1bed415_1         --> 1.12-1
#     libxml2:            2.9.8-h26e45fe_1        --> 2.9.4-0
#     libxslt:            1.1.32-h1312cb7_0       --> 1.1.29-0
#     llvmlite:           0.24.0-py27hdbcaa40_0   --> 0.18.0-py27_0
#     lxml:               4.2.5-py27hefd8a0e_0    --> 3.7.3-py27_0
#     markupsafe:         1.0-py27h14c3975_1      --> 0.23-py27_2
#     matplotlib:         2.2.3-py27hb69df0a_0    --> 2.0.2-np112py27_0
#     mistune:            0.8.3-py27h14c3975_1    --> 0.7.4-py27_0
#     mkl:                2019.0-118              --> 2017.0.1-0
#     mkl-service:        1.1.2-py27h90e4bf4_5    --> 1.1.2-py27_3
#     mpmath:             1.0.0-py27_2            --> 0.19-py27_1
#     msgpack-python:     0.5.6-py27h6bb024c_1    --> 0.4.8-py27_0
#     multipledispatch:   0.6.0-py27_0            --> 0.4.9-py27_0
#     navigator-updater:  0.2.1-py27_0            --> 0.1.0-py27_0
#     nbconvert:          5.4.0-py27_1            --> 5.1.1-py27_0
#     nbformat:           4.4.0-py27_0            --> 4.3.0-py27_0
#     networkx:           2.1-py27_0              --> 1.11-py27_0
#     nltk:               3.3.0-py27_0            --> 3.2.3-py27_0
#     nose:               1.3.7-py27_2            --> 1.3.7-py27_1
#     notebook:           5.6.0-py27_0            --> 5.0.0-py27_0
#     numba:              0.39.0-py27h04863e7_0   --> 0.33.0-np112py27_0
#     numexpr:            2.6.8-py27hd89afb7_0    --> 2.6.2-np112py27_0
#     numpy:              1.15.1-py27h1d66e8a_0   --> 1.12.1-py27_0
#     numpydoc:           0.8.0-py27_0            --> 0.6.0-py27_0
#     odo:                0.5.1-py27_0            --> 0.5.0-py27_1
#     olefile:            0.46-py27_0             --> 0.44-py27_0
#     openpyxl:           2.5.6-py27_0            --> 2.4.7-py27_0
#     openssl:            1.0.2p-h14c3975_0       --> 1.0.2l-0
#     packaging:          17.1-py27_0             --> 16.8-py27_0
#     pandas:             0.23.4-py27h04863e7_0   --> 0.20.1-np112py27_0
#     pandocfilters:      1.4.2-py27_1            --> 1.4.1-py27_0
#     pango:              1.42.4-h049681c_0       --> 1.40.3-1
#     path.py:            11.1.0-py27_0           --> 10.3.1-py27_0
#     pathlib2:           2.3.2-py27_0            --> 2.2.1-py27_0
#     patsy:              0.5.0-py27_0            --> 0.4.1-py27_0
#     pcre:               8.42-h439df22_0         --> 8.39-1
#     pep8:               1.7.1-py27_0            --> 1.7.0-py27_0
#     pexpect:            4.6.0-py27_0            --> 4.2.1-py27_0
#     pillow:             5.2.0-py27heded4f4_0    --> 4.1.1-py27_0
#     pip:                10.0.1-py27_0           --> 9.0.1-py27_1
#     pixman:             0.34.0-hceecf20_3       --> 0.34.0-0
#     ply:                3.11-py27_0             --> 3.10-py27_0
#     prompt_toolkit:     1.0.15-py27_0           --> 1.0.14-py27_0
#     psutil:             5.4.7-py27h14c3975_0    --> 5.2.2-py27_0
#     ptyprocess:         0.6.0-py27_0            --> 0.5.1-py27_0
#     py:                 1.6.0-py27_0            --> 1.4.33-py27_0
#     pycairo:            1.17.1-py27h2a1e443_0   --> 1.10.0-py27_0
#     pycosat:            0.6.3-py27h14c3975_0    --> 0.6.2-py27_0
#     pycparser:          2.18-py27_1             --> 2.17-py27_0
#     pycrypto:           2.6.1-py27h14c3975_9    --> 2.6.1-py27_6
#     pycurl:             7.43.0.2-py27hb7f436b_0 --> 7.43.0-py27_2
#     pyflakes:           2.0.0-py27_0            --> 1.5.0-py27_0
#     pylint:             1.9.2-py27_0            --> 1.6.4-py27_1
#     pyodbc:             4.0.24-py27he6710b0_0   --> 4.0.16-py27_0
#     pyopenssl:          18.0.0-py27_0           --> 17.0.0-py27_0
#     pyparsing:          2.2.0-py27_1            --> 2.1.4-py27_0
#     pyqt:               5.9.2-py27h05f1152_2    --> 5.6.0-py27_2
#     pytables:           3.4.4-py27ha205bf6_0    --> 3.3.0-np112py27_0
#     pytest:             3.8.0-py27_0            --> 3.0.7-py27_0
#     python:             2.7.15-h1571d57_0       --> 2.7.13-0
#     python-dateutil:    2.7.3-py27_0            --> 2.6.0-py27_0
#     pytz:               2018.5-py27_0           --> 2017.2-py27_0
#     pywavelets:         1.0.0-py27hdd07704_0    --> 0.5.2-np112py27_0
#     pyyaml:             3.13-py27h14c3975_0     --> 3.12-py27_0
#     pyzmq:              17.1.2-py27h14c3975_0   --> 16.0.2-py27_0
#     qt:                 5.9.6-h8703b6f_2        --> 5.6.2-4
#     qtconsole:          4.4.1-py27_0            --> 4.3.0-py27_0
#     qtpy:               1.5.0-py27_0            --> 1.2.1-py27_0
#     readline:           7.0-h7b6447c_5          --> 6.2-2
#     requests:           2.19.1-py27_0           --> 2.14.2-py27_0
#     rope:               0.11.0-py27_0           --> 0.9.4-py27_1
#     ruamel_yaml:        0.15.46-py27h14c3975_0  --> 0.11.14-py27_1
#     scandir:            1.9.0-py27h14c3975_0    --> 1.5-py27_0
#     scikit-image:       0.14.0-py27hf484d3e_1   --> 0.13.0-np112py27_0
#     scikit-learn:       0.19.2-py27h4989274_0   --> 0.18.1-np112py27_1
#     scipy:              1.1.0-py27hfa4b5c9_1    --> 0.19.0-np112py27_0
#     seaborn:            0.9.0-py27_0            --> 0.7.1-py27_0
#     setuptools:         40.2.0-py27_0           --> 27.2.0-py27_0
#     simplegeneric:      0.8.1-py27_2            --> 0.8.1-py27_1
#     sip:                4.19.8-py27hf484d3e_0   --> 4.18-py27_0
#     six:                1.11.0-py27_1           --> 1.10.0-py27_0
#     sortedcollections:  1.0.1-py27_0            --> 0.5.3-py27_0
#     sortedcontainers:   2.0.5-py27_0            --> 1.5.7-py27_0
#     sphinx:             1.7.9-py27_0            --> 1.5.6-py27_0
#     spyder:             3.3.1-py27_1            --> 3.1.4-py27_0
#     sqlalchemy:         1.2.11-py27h7b6447c_0   --> 1.1.9-py27_0
#     sqlite:             3.24.0-h84994c4_0       --> 3.13.0-0
#     ssl_match_hostname: 3.5.0.1-py27_2          --> 3.4.0.2-py27_1
#     statsmodels:        0.9.0-py27h035aef0_0    --> 0.8.0-np112py27_0
#     subprocess32:       3.5.2-py27h14c3975_0    --> 3.2.7-py27_0
#     sympy:              1.2-py27_0              --> 1.0-py27_0
#     terminado:          0.8.1-py27_1            --> 0.6-py27_0
#     testpath:           0.3.1-py27_0            --> 0.3-py27_0
#     tk:                 8.6.8-hbc83047_0        --> 8.5.18-0
#     toolz:              0.9.0-py27_0            --> 0.8.2-py27_0
#     tornado:            5.1-py27h14c3975_0      --> 4.5.1-py27_0
#     unixodbc:           2.3.7-h14c3975_0        --> 2.3.4-0
#     werkzeug:           0.14.1-py27_0           --> 0.12.2-py27_0
#     wheel:              0.31.1-py27_0           --> 0.29.0-py27_0
#     widgetsnbextension: 3.4.1-py27_0            --> 2.0.0-py27_0
#     wrapt:              1.10.11-py27h14c3975_2  --> 1.10.10-py27_0
#     xlrd:               1.1.0-py27_1            --> 1.0.0-py27_0
#     xlsxwriter:         1.1.0-py27_0            --> 0.9.6-py27_0
#     xlwt:               1.3.0-py27_0            --> 1.2.0-py27_0
#     xz:                 5.2.4-h14c3975_4        --> 5.2.2-1
#     yaml:               0.1.7-had09818_2        --> 0.1.6-0
#     zeromq:             4.2.5-hf484d3e_1        --> 4.1.5-0
#     zict:               0.1.3-py27_0            --> 0.1.2-py27_0
#     zlib:               1.2.11-ha838bed_2       --> 1.2.8-3
#
#
# Downloading and Extracting Packages
# ptyprocess-0.5.1     | 19 KB     | : 100% 1.0/1 [00:00<00:00,  4.65it/s]
# pycurl-7.43.0        | 132 KB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
# cffi-1.10.0          | 329 KB    | : 100% 1.0/1 [00:00<00:00,  6.08it/s]
# pylint-1.6.4         | 316 KB    | : 100% 1.0/1 [00:00<00:00,  5.17s/it]
# yaml-0.1.6           | 246 KB    | : 100% 1.0/1 [00:00<00:00,  8.77it/s]
# ruamel_yaml-0.11.14  | 361 KB    | : 100% 1.0/1 [00:00<00:00,  6.03s/it]
# openssl-1.0.2l       | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.40it/s]
# clyent-1.2.2         | 15 KB     | : 100% 1.0/1 [00:00<00:00, 15.68it/s]
# pango-1.40.3         | 938 KB    | : 100% 1.0/1 [00:00<00:00,  3.18it/s]
# sortedcontainers-1.5 | 44 KB     | : 100% 1.0/1 [00:00<00:00,  3.78it/s]
# pcre-8.39            | 656 KB    | : 100% 1.0/1 [00:00<00:00,  4.62it/s]
# ipython-5.3.0        | 974 KB    | : 100% 1.0/1 [00:00<00:00,  1.50it/s]
# gst-plugins-base-1.8 | 3.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.17s/it]
# ipykernel-4.6.1      | 135 KB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
# prompt_toolkit-1.0.1 | 330 KB    | : 100% 1.0/1 [00:00<00:00,  1.94it/s]
# cytoolz-0.8.2        | 913 KB    | : 100% 1.0/1 [00:00<00:00,  1.88it/s]
# hdf5-1.8.17          | 1.9 MB    | : 100% 1.0/1 [00:00<00:00,  1.47it/s]
# freetype-2.5.5       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.30it/s]
# jupyter_core-4.3.0   | 59 KB     | : 100% 1.0/1 [00:00<00:00,  3.78it/s]
# bleach-1.5.0         | 21 KB     | : 100% 1.0/1 [00:00<00:00, 15.69it/s]
# libgfortran-3.0.0    | 281 KB    | : 100% 1.0/1 [00:00<00:00,  8.79it/s]
# imagesize-0.7.1      | 3 KB      | : 100% 1.0/1 [00:00<00:00,  4.65it/s]
# widgetsnbextension-2 | 878 KB    | : 100% 1.0/1 [00:00<00:00,  1.62it/s]
# libiconv-1.14        | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
# pyflakes-1.5.0       | 80 KB     | : 100% 1.0/1 [00:00<00:00,  3.78it/s]
# icu-54.1             | 11.3 MB   | : 100% 1.0/1 [00:02<00:00,  2.23s/it]
# zlib-1.2.8           | 101 KB    | : 100% 1.0/1 [00:00<00:00, 15.61it/s]
# odo-0.5.0            | 175 KB    | : 100% 1.0/1 [00:00<00:00,  2.45s/it]
# jpeg-9b              | 941 KB    | : 100% 1.0/1 [00:00<00:00,  1.63it/s]
# pyparsing-2.1.4      | 70 KB     | : 100% 1.0/1 [00:00<00:00,  3.75it/s]
# pep8-1.7.0           | 47 KB     | : 100% 1.0/1 [00:00<00:00, 15.19it/s]
# numexpr-2.6.2        | 353 KB    | : 100% 1.0/1 [00:00<00:00,  2.41it/s]
# libffi-3.2.1         | 38 KB     | : 100% 1.0/1 [00:00<00:00, 15.66it/s]
# wrapt-1.10.10        | 64 KB     | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# scandir-1.5          | 40 KB     | : 100% 1.0/1 [00:00<00:00, 15.75it/s]
# requests-2.14.2      | 700 KB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
# anaconda-custom      | 3 KB      | : 100% 1.0/1 [00:00<00:00, 31.52it/s]
# xlwt-1.2.0           | 160 KB    | : 100% 1.0/1 [00:00<00:00,  3.18it/s]
# notebook-5.0.0       | 5.3 MB    | : 100% 1.0/1 [00:02<00:00,  2.47s/it]
# seaborn-0.7.1        | 272 KB    | : 100% 1.0/1 [00:00<00:00,  4.89s/it]
# anaconda-navigator-1 | 3.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.15it/s]
# python-2.7.13        | 11.5 MB   | : 100% 1.0/1 [00:04<00:00,  4.87s/it]
# pycairo-1.10.0       | 81 KB     | : 100% 1.0/1 [00:00<00:00, 15.66it/s]
# tk-8.5.18            | 1.9 MB    | : 100% 1.0/1 [00:00<00:00,  1.61it/s]
# libxslt-1.1.29       | 983 KB    | : 100% 1.0/1 [00:00<00:00,  3.18it/s]
# greenlet-0.4.12      | 37 KB     | : 100% 1.0/1 [00:00<00:00,  3.78it/s]
# patsy-0.4.1          | 325 KB    | : 100% 1.0/1 [00:00<00:00,  5.37s/it]
# libtool-2.4.2        | 547 KB    | : 100% 1.0/1 [00:00<00:00,  4.50it/s]
# py-1.4.33            | 130 KB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
# _license-1.1         | 271 KB    | : 100% 1.0/1 [00:00<00:00,  8.68it/s]
# six-1.10.0           | 16 KB     | : 100% 1.0/1 [00:00<00:00,  4.66it/s]
# jinja2-2.9.6         | 348 KB    | : 100% 1.0/1 [00:00<00:00,  2.38it/s]
# html5lib-0.999       | 172 KB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
# docutils-0.13.1      | 679 KB    | : 100% 1.0/1 [00:00<00:00,  1.30it/s]
# pillow-4.1.1         | 840 KB    | : 100% 1.0/1 [00:00<00:00,  1.40it/s]
# anaconda-client-1.6. | 129 KB    | : 100% 1.0/1 [00:00<00:00,  5.70it/s]
# libpng-1.6.27        | 219 KB    | : 100% 1.0/1 [00:00<00:00,  8.03it/s]
# ssl_match_hostname-3 | 6 KB      | : 100% 1.0/1 [00:00<00:00,  6.11it/s]
# sqlite-3.13.0        | 4.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.15it/s]
# toolz-0.8.2          | 89 KB     | : 100% 1.0/1 [00:00<00:00,  8.63it/s]
# jupyter-1.0.0        | 3 KB      | : 100% 1.0/1 [00:00<00:00, 15.60it/s]
# boto-2.46.1          | 1.4 MB    | : 100% 1.0/1 [00:01<00:00,  1.02s/it]
# libxcb-1.12          | 1.5 MB    | : 100% 1.0/1 [00:03<00:00,  3.20s/it]
# mkl-service-1.1.2    | 15 KB     | : 100% 1.0/1 [00:00<00:00, 31.20it/s]
# jupyter_console-5.1. | 33 KB     | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# psutil-5.2.2         | 260 KB    | : 100% 1.0/1 [00:00<00:00,  4.20s/it]
# lazy-object-proxy-1. | 53 KB     | : 100% 1.0/1 [00:00<00:00,  3.18it/s]
# pathlib2-2.2.1       | 30 KB     | : 100% 1.0/1 [00:00<00:00,  3.78it/s]
# idna-2.5             | 121 KB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
# sqlalchemy-1.1.9     | 1.4 MB    | : 100% 1.0/1 [00:01<00:00,  1.12s/it]
# babel-2.4.0          | 4.9 MB    | : 100% 1.0/1 [00:01<00:00,  1.57s/it]
# sphinx-1.5.6         | 1.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.32s/it]
# blaze-0.10.1         | 577 KB    | : 100% 1.0/1 [00:00<00:00,  3.18it/s]
# zict-0.1.2           | 17 KB     | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# libsodium-1.0.10     | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  2.41it/s]
# bokeh-0.12.5         | 4.1 MB    | : 100% 1.0/1 [00:02<00:00,  2.69s/it]
# pytz-2017.2          | 204 KB    | : 100% 1.0/1 [00:00<00:00,  1.93it/s]
# certifi-2019.3.9     | 155 KB    | : 100% 1.0/1 [00:00<00:00, 15.71it/s]
# cryptography-1.8.1   | 850 KB    | : 100% 1.0/1 [00:00<00:00,  1.40it/s]
# astroid-1.4.9        | 251 KB    | : 100% 1.0/1 [00:00<00:00,  6.09it/s]
# pexpect-4.2.1        | 69 KB     | : 100% 1.0/1 [00:00<00:00,  3.77it/s]
# gevent-1.2.1         | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.22it/s]
# astropy-1.3.2        | 8.8 MB    | : 100% 1.0/1 [00:02<00:00,  2.93s/it]
# gstreamer-1.8.0      | 2.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.31it/s]
# cython-0.25.2        | 5.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.92s/it]
# chardet-3.0.3        | 175 KB    | : 100% 1.0/1 [00:00<00:00,  6.82it/s]
# setuptools-27.2.0    | 521 KB    | : 100% 1.0/1 [00:00<00:00,  5.92it/s]
# matplotlib-2.0.2     | 10.6 MB   | : 100% 1.0/1 [00:02<00:00,  2.87s/it]
# nltk-3.2.3           | 1.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.22s/it]
# pyqt-5.6.0           | 5.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.98s/it]
# libxml2-2.9.4        | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  1.23it/s]
# dask-0.14.3          | 812 KB    | : 100% 1.0/1 [00:00<00:00,  1.40it/s]
# curl-7.52.1          | 558 KB    | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# grin-1.2.1           | 24 KB     | : 100% 1.0/1 [00:00<00:00,  4.66it/s]
# scipy-0.19.0         | 35.3 MB   | : 100% 1.0/1 [00:10<00:00, 10.72s/it]
# python-dateutil-2.6. | 232 KB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
# unixodbc-2.3.4       | 688 KB    | : 100% 1.0/1 [00:00<00:00,  3.17it/s]
# zeromq-4.1.5         | 4.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.02s/it]
# scikit-learn-0.18.1  | 11.0 MB   | : 100% 1.0/1 [00:03<00:00,  3.32s/it]
# get_terminal_size-1. | 4 KB      | : 100% 1.0/1 [00:00<00:00,  4.65it/s]
# enum34-1.1.6         | 53 KB     | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# entrypoints-0.2.2    | 9 KB      | : 100% 1.0/1 [00:00<00:00,  6.11it/s]
# packaging-16.8       | 30 KB     | : 100% 1.0/1 [00:00<00:00,  4.63it/s]
# bitarray-0.8.1       | 89 KB     | : 100% 1.0/1 [00:00<00:00,  8.55it/s]
# terminado-0.6        | 18 KB     | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# pycrypto-2.6.1       | 459 KB    | : 100% 1.0/1 [00:00<00:00,  1.40it/s]
# anaconda-project-0.6 | 208 KB    | : 100% 1.0/1 [00:00<00:00,  4.66it/s]
# openpyxl-2.4.7       | 285 KB    | : 100% 1.0/1 [00:00<00:00,  1.74it/s]
# ply-3.10             | 75 KB     | : 100% 1.0/1 [00:00<00:00,  3.18it/s]
# xz-5.2.2             | 669 KB    | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# rope-0.9.4           | 225 KB    | : 100% 1.0/1 [00:00<00:00,  4.60it/s]
# lxml-3.7.3           | 2.9 MB    | : 100% 1.0/1 [00:01<00:00,  1.22s/it]
# networkx-1.11        | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.08it/s]
# bottleneck-1.2.1     | 304 KB    | : 100% 1.0/1 [00:00<00:00,  5.42s/it]
# jbig-2.1             | 29 KB     | : 100% 1.0/1 [00:00<00:00, 15.68it/s]
# isort-4.2.5          | 51 KB     | : 100% 1.0/1 [00:00<00:00,  3.79it/s]
# pywavelets-0.5.2     | 5.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.52s/it]
# statsmodels-0.8.0    | 7.3 MB    | : 100% 1.0/1 [00:02<00:00,  2.98s/it]
# glib-2.50.2          | 5.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.52s/it]
# numba-0.33.0         | 2.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.58s/it]
# h5py-2.7.0           | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.03it/s]
# msgpack-python-0.4.8 | 209 KB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
# backports-1.0        | 1 KB      | : 100% 1.0/1 [00:00<00:00, 15.62it/s]
# cairo-1.14.8         | 609 KB    | : 100% 1.0/1 [00:00<00:00,  4.64it/s]
# libgcc-5.2.0         | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.11it/s]
# futures-3.1.1        | 22 KB     | : 100% 1.0/1 [00:00<00:00,  3.78it/s]
# fastcache-1.0.2      | 41 KB     | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# sip-4.18             | 264 KB    | : 100% 1.0/1 [00:00<00:00,  8.78it/s]
# olefile-0.44         | 52 KB     | : 100% 1.0/1 [00:00<00:00,  2.73it/s]
# subprocess32-3.2.7   | 55 KB     | : 100% 1.0/1 [00:00<00:00,  3.79it/s]
# pycosat-0.6.2        | 194 KB    | : 100% 1.0/1 [00:00<00:00,  3.18it/s]
# asn1crypto-0.22.0    | 145 KB    | : 100% 1.0/1 [00:00<00:00,  7.41it/s]
# werkzeug-0.12.2      | 408 KB    | : 100% 1.0/1 [00:00<00:00,  1.77it/s]
# sortedcollections-0. | 13 KB     | : 100% 1.0/1 [00:00<00:00,  3.18it/s]
# mistune-0.7.4        | 605 KB    | : 100% 1.0/1 [00:00<00:00,  2.15it/s]
# harfbuzz-0.9.39      | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
# fontconfig-2.12.1    | 429 KB    | : 100% 1.0/1 [00:00<00:00,  6.10it/s]
# dbus-1.10.10         | 2.4 MB    | : 100% 1.0/1 [00:01<00:00,  1.07s/it]
# pandas-0.20.1        | 19.2 MB   | : 100% 1.0/1 [00:06<00:00,  6.14s/it]
# pyyaml-3.12          | 313 KB    | : 100% 1.0/1 [00:00<00:00,  6.09it/s]
# alabaster-0.7.10     | 14 KB     | : 100% 1.0/1 [00:00<00:00, 15.60it/s]
# sympy-1.0            | 5.6 MB    | : 100% 1.0/1 [00:02<00:00,  2.77s/it]
# simplegeneric-0.8.1  | 7 KB      | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# libssh2-1.8.0        | 243 KB    | : 100% 1.0/1 [00:00<00:00,  3.78it/s]
# blosc-1.2.3          | 18 KB     | : 100% 1.0/1 [00:00<00:00,  3.78it/s]
# markupsafe-0.23      | 31 KB     | : 100% 1.0/1 [00:00<00:00, 15.54it/s]
# flask-0.12.2         | 102 KB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
# conda-4.3.27         | 508 KB    | : 100% 1.0/1 [00:00<00:00,  6.48s/it]
# wheel-0.29.0         | 81 KB     | : 100% 1.0/1 [00:00<00:00,  8.77it/s]
# xlrd-1.0.0           | 181 KB    | : 100% 1.0/1 [00:00<00:00,  3.18it/s]
# jdcal-1.3            | 8 KB      | : 100% 1.0/1 [00:00<00:00,  6.09it/s]
# spyder-kernels-1.3.2 | 63 KB     | : 100% 1.0/1 [00:00<00:00,  8.79it/s]
# pixman-0.34.0        | 3.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.47s/it]
# testpath-0.3         | 15 KB     | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# scikit-image-0.13.0  | 31.6 MB   | : 100% 1.0/1 [00:07<00:00,  7.19s/it]
# pandocfilters-1.4.1  | 12 KB     | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# ipywidgets-6.0.0     | 63 KB     | : 100% 1.0/1 [00:00<00:00,  8.80it/s]
# itsdangerous-0.24    | 16 KB     | : 100% 1.0/1 [00:00<00:00, 15.69it/s]
# functools32-3.2.3.2  | 15 KB     | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# ...
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_base.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_base.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_cache.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_cache.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_callbacks.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_callbacks.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_context.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_context.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_core.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_core.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_delayed.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_delayed.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_distributed.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_distributed.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_dot.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_dot.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_multiprocessing.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_multiprocessing.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_order.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_order.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_rewrite.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_rewrite.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_sharedict.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_sharedict.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_sizeof.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_sizeof.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_threaded.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_threaded.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_utils.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/tests/test_utils.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/threaded.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/threaded.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/utils.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/utils.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/utils_test.py'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::dask-0.14.3-py27_1' cannot be installed due to a
# path collision for 'lib/python2.7/site-packages/dask/utils_test.pyc'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::dask-core-0.19.1-py27_0', which is already installed in the prefix.
#
#
# ClobberError: The package 'defaults::ipywidgets-6.0.0-py27_0' cannot be installed due to a
# path collision for 'etc/jupyter/nbconfig/notebook.json'.
# This path already exists in the target prefix, and it won't be removed by
# an uninstall action in this transaction. The path appears to be coming from
# the package 'defaults::_ipyw_jlab_nb_ext_conf-0.1.0-py27_0', which is already installed in the prefix.
#
#
# ClobberError: This transaction has incompatible packages due to a shared path.
#   packages: defaults::ca-certificates-2019.1.23-0, defaults::openssl-1.0.2l-0
#   path: 'ssl/cert.pem'
#
#
# ClobberError: This transaction has incompatible packages due to a shared path.
#   packages: defaults::libgcc-5.2.0-0, defaults::libgfortran-3.0.0-1
#   path: 'lib/libgfortran.so.3.0.0'
#
#
# ClobberError: This transaction has incompatible packages due to a shared path.
#   packages: defaults::ca-certificates-2019.1.23-0, defaults::openssl-1.0.2l-0
#   path: 'ssl/cacert.pem'
#
#
# ClobberError: This transaction has incompatible packages due to a shared path.
#   packages: defaults::libgcc-5.2.0-0, defaults::libgfortran-3.0.0-1
#   path: 'lib/libgfortran.so.3'
#
#
#
# |
# done
# done

# %%
# !python3 ./drive/My\ Drive/Residual_HSI-Colab/SSRN/SSRN_UP.py
#!python3 ./drive/My\ Drive/Residual_HSI-Colab/SSRN/Load_UP.py
# Out:
# Using TensorFlow backend.
# hello
# (610, 340)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype uint16 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# tcmalloc: large alloc 1554276352 bytes == 0x6153a000 @  0x7f8a96253001 0x7f8a93d9ade5 0x7f8a93dff691 0x7f8a93e0176f 0x7f8a93e9a0b8 0x5030d5 0x506859 0x504c28 0x506393 0x634d52 0x634e0a 0x6385c8 0x63915a 0x4a6f10 0x7f8a95e4eb97 0x5afa0a
# # 1 Iteration
# input shape: 103
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# input shape: (None, 7, 7, 49, 24)
# conv_spc_result shape: (None, 7, 7, 1, 128)
# conv1 shape: (None, 5, 5, 1, 24)
# input shape: (None, 5, 5, 1, 24)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# (4281, 7, 7, 103) (34214, 7, 7, 103)
# ./drive/My Drive/Residual_HSI-Colab/SSRN/SSRN_UP.py:186: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   nb_epoch=nb_epoch, shuffle=True, callbacks=[earlyStopping6, saveBestModel6])
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 4281 samples, validate on 4281 samples
# Epoch 1/200
# 2019-05-06 22:09:25.596309: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-06 22:09:25.596649: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1d2d1e0 executing computations on platform Host. Devices:
# 2019-05-06 22:09:25.596714: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-06 22:09:25.808222: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-06 22:09:25.808889: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1d2cdc0 executing computations on platform CUDA. Devices:
# 2019-05-06 22:09:25.808928: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2019-05-06 22:09:25.809382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# totalMemory: 14.73GiB freeMemory: 14.60GiB
# 2019-05-06 22:09:25.809419: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-05-06 22:09:26.244610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-05-06 22:09:26.244708: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-05-06 22:09:26.244726: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-05-06 22:09:26.245013: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-05-06 22:09:26.245074: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14115 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2019-05-06 22:09:28.312167: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# 4281/4281 [==============================] - 13s 3ms/step - loss: 1.2028 - acc: 0.6396 - val_loss: 0.4432 - val_acc: 0.9390
#
# Epoch 00001: val_loss improved from inf to 0.44322, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 2/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.7599 - acc: 0.8010 - val_loss: 0.3636 - val_acc: 0.9194
#
# Epoch 00002: val_loss improved from 0.44322 to 0.36359, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 3/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.5995 - acc: 0.8484 - val_loss: 0.2861 - val_acc: 0.9306
#
# Epoch 00003: val_loss improved from 0.36359 to 0.28614, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 4/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.5074 - acc: 0.8657 - val_loss: 0.2391 - val_acc: 0.9554
#
# Epoch 00004: val_loss improved from 0.28614 to 0.23910, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 5/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.4513 - acc: 0.8865 - val_loss: 0.1533 - val_acc: 0.9801
#
# Epoch 00005: val_loss improved from 0.23910 to 0.15334, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 6/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.4087 - acc: 0.8956 - val_loss: 0.1727 - val_acc: 0.9752
#
# Epoch 00006: val_loss did not improve from 0.15334
# Epoch 7/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.3866 - acc: 0.9007 - val_loss: 0.1108 - val_acc: 0.9890
#
# Epoch 00007: val_loss improved from 0.15334 to 0.11085, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 8/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.3577 - acc: 0.9115 - val_loss: 0.0917 - val_acc: 0.9921
#
# Epoch 00008: val_loss improved from 0.11085 to 0.09165, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 9/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.3143 - acc: 0.9231 - val_loss: 0.1360 - val_acc: 0.9799
#
# Epoch 00009: val_loss did not improve from 0.09165
# Epoch 10/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.3066 - acc: 0.9262 - val_loss: 0.1012 - val_acc: 0.9874
#
# Epoch 00010: val_loss did not improve from 0.09165
# Epoch 11/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.3034 - acc: 0.9234 - val_loss: 0.0990 - val_acc: 0.9900
#
# Epoch 00011: val_loss did not improve from 0.09165
# Epoch 12/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.2693 - acc: 0.9299 - val_loss: 0.0896 - val_acc: 0.9923
#
# Epoch 00012: val_loss improved from 0.09165 to 0.08962, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 13/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.2662 - acc: 0.9346 - val_loss: 0.1209 - val_acc: 0.9804
#
# Epoch 00013: val_loss did not improve from 0.08962
# Epoch 14/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.2560 - acc: 0.9386 - val_loss: 0.0759 - val_acc: 0.9960
#
# Epoch 00014: val_loss improved from 0.08962 to 0.07589, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 15/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.2514 - acc: 0.9402 - val_loss: 0.0908 - val_acc: 0.9893
#
# Epoch 00015: val_loss did not improve from 0.07589
# Epoch 16/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.2245 - acc: 0.9435 - val_loss: 0.0967 - val_acc: 0.9895
#
# Epoch 00016: val_loss did not improve from 0.07589
# Epoch 17/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.2296 - acc: 0.9465 - val_loss: 0.0879 - val_acc: 0.9900
#
# Epoch 00017: val_loss did not improve from 0.07589
# Epoch 18/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.2122 - acc: 0.9488 - val_loss: 0.0958 - val_acc: 0.9874
#
# Epoch 00018: val_loss did not improve from 0.07589
# Epoch 19/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.2176 - acc: 0.9458 - val_loss: 0.1008 - val_acc: 0.9860
#
# Epoch 00019: val_loss did not improve from 0.07589
# Epoch 20/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.2134 - acc: 0.9428 - val_loss: 0.0740 - val_acc: 0.9932
#
# Epoch 00020: val_loss improved from 0.07589 to 0.07399, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 21/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1920 - acc: 0.9521 - val_loss: 0.0689 - val_acc: 0.9951
#
# Epoch 00021: val_loss improved from 0.07399 to 0.06891, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 22/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1810 - acc: 0.9594 - val_loss: 0.0705 - val_acc: 0.9963
#
# Epoch 00022: val_loss did not improve from 0.06891
# Epoch 23/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1827 - acc: 0.9523 - val_loss: 0.0703 - val_acc: 0.9956
#
# Epoch 00023: val_loss did not improve from 0.06891
# Epoch 24/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1808 - acc: 0.9547 - val_loss: 0.0687 - val_acc: 0.9949
#
# Epoch 00024: val_loss improved from 0.06891 to 0.06875, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 25/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1749 - acc: 0.9591 - val_loss: 0.0673 - val_acc: 0.9963
#
# Epoch 00025: val_loss improved from 0.06875 to 0.06731, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 26/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1882 - acc: 0.9535 - val_loss: 0.0695 - val_acc: 0.9949
#
# Epoch 00026: val_loss did not improve from 0.06731
# Epoch 27/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.1727 - acc: 0.9561 - val_loss: 0.0701 - val_acc: 0.9958
#
# Epoch 00027: val_loss did not improve from 0.06731
# Epoch 28/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1830 - acc: 0.9530 - val_loss: 0.0641 - val_acc: 0.9956
#
# Epoch 00028: val_loss improved from 0.06731 to 0.06406, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 29/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1868 - acc: 0.9523 - val_loss: 0.0658 - val_acc: 0.9956
#
# Epoch 00029: val_loss did not improve from 0.06406
# Epoch 30/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1720 - acc: 0.9552 - val_loss: 0.0637 - val_acc: 0.9958
#
# Epoch 00030: val_loss improved from 0.06406 to 0.06371, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 31/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1749 - acc: 0.9526 - val_loss: 0.0738 - val_acc: 0.9932
#
# Epoch 00031: val_loss did not improve from 0.06371
# Epoch 32/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1858 - acc: 0.9512 - val_loss: 0.0677 - val_acc: 0.9944
#
# Epoch 00032: val_loss did not improve from 0.06371
# Epoch 33/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1577 - acc: 0.9601 - val_loss: 0.0621 - val_acc: 0.9963
#
# Epoch 00033: val_loss improved from 0.06371 to 0.06211, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 34/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1502 - acc: 0.9638 - val_loss: 0.0594 - val_acc: 0.9965
#
# Epoch 00034: val_loss improved from 0.06211 to 0.05941, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 35/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1445 - acc: 0.9659 - val_loss: 0.0739 - val_acc: 0.9923
#
# Epoch 00035: val_loss did not improve from 0.05941
# Epoch 36/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1612 - acc: 0.9594 - val_loss: 0.0706 - val_acc: 0.9932
#
# Epoch 00036: val_loss did not improve from 0.05941
# Epoch 37/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1519 - acc: 0.9610 - val_loss: 0.0671 - val_acc: 0.9946
#
# Epoch 00037: val_loss did not improve from 0.05941
# Epoch 38/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.1599 - acc: 0.9612 - val_loss: 0.0624 - val_acc: 0.9960
#
# Epoch 00038: val_loss did not improve from 0.05941
# Epoch 39/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1578 - acc: 0.9601 - val_loss: 0.0602 - val_acc: 0.9963
#
# Epoch 00039: val_loss did not improve from 0.05941
# Epoch 40/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1511 - acc: 0.9626 - val_loss: 0.0639 - val_acc: 0.9953
#
# Epoch 00040: val_loss did not improve from 0.05941
# Epoch 41/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.1377 - acc: 0.9636 - val_loss: 0.0805 - val_acc: 0.9918
#
# Epoch 00041: val_loss did not improve from 0.05941
# Epoch 42/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.1299 - acc: 0.9682 - val_loss: 0.0605 - val_acc: 0.9965
#
# Epoch 00042: val_loss did not improve from 0.05941
# Epoch 43/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1579 - acc: 0.9573 - val_loss: 0.0621 - val_acc: 0.9960
#
# Epoch 00043: val_loss did not improve from 0.05941
# Epoch 44/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1634 - acc: 0.9577 - val_loss: 0.1107 - val_acc: 0.9759
#
# Epoch 00044: val_loss did not improve from 0.05941
# Epoch 45/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1536 - acc: 0.9605 - val_loss: 0.0615 - val_acc: 0.9960
#
# Epoch 00045: val_loss did not improve from 0.05941
# Epoch 46/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1430 - acc: 0.9638 - val_loss: 0.0524 - val_acc: 0.9977
#
# Epoch 00046: val_loss improved from 0.05941 to 0.05236, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 47/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1273 - acc: 0.9701 - val_loss: 0.1068 - val_acc: 0.9745
#
# Epoch 00047: val_loss did not improve from 0.05236
# Epoch 48/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1450 - acc: 0.9610 - val_loss: 0.0545 - val_acc: 0.9965
#
# Epoch 00048: val_loss did not improve from 0.05236
# Epoch 49/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.1240 - acc: 0.9689 - val_loss: 0.0609 - val_acc: 0.9963
#
# Epoch 00049: val_loss did not improve from 0.05236
# Epoch 50/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1393 - acc: 0.9640 - val_loss: 0.0515 - val_acc: 0.9979
#
# Epoch 00050: val_loss improved from 0.05236 to 0.05149, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 51/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1402 - acc: 0.9612 - val_loss: 0.0534 - val_acc: 0.9974
#
# Epoch 00051: val_loss did not improve from 0.05149
# Epoch 52/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1372 - acc: 0.9617 - val_loss: 0.0619 - val_acc: 0.9960
#
# Epoch 00052: val_loss did not improve from 0.05149
# Epoch 53/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1344 - acc: 0.9654 - val_loss: 0.0505 - val_acc: 0.9979
#
# Epoch 00053: val_loss improved from 0.05149 to 0.05055, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 54/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1422 - acc: 0.9668 - val_loss: 0.0521 - val_acc: 0.9981
#
# Epoch 00054: val_loss did not improve from 0.05055
# Epoch 55/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1257 - acc: 0.9678 - val_loss: 0.0605 - val_acc: 0.9958
#
# Epoch 00055: val_loss did not improve from 0.05055
# Epoch 56/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1402 - acc: 0.9661 - val_loss: 0.0513 - val_acc: 0.9979
#
# Epoch 00056: val_loss did not improve from 0.05055
# Epoch 57/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1257 - acc: 0.9685 - val_loss: 0.0516 - val_acc: 0.9972
#
# Epoch 00057: val_loss did not improve from 0.05055
# Epoch 58/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1228 - acc: 0.9694 - val_loss: 0.0521 - val_acc: 0.9974
#
# Epoch 00058: val_loss did not improve from 0.05055
# Epoch 59/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1318 - acc: 0.9645 - val_loss: 0.0542 - val_acc: 0.9972
#
# Epoch 00059: val_loss did not improve from 0.05055
# Epoch 60/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.1315 - acc: 0.9673 - val_loss: 0.0612 - val_acc: 0.9956
#
# Epoch 00060: val_loss did not improve from 0.05055
# Epoch 61/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1287 - acc: 0.9687 - val_loss: 0.0511 - val_acc: 0.9965
#
# Epoch 00061: val_loss did not improve from 0.05055
# Epoch 62/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1301 - acc: 0.9701 - val_loss: 0.0577 - val_acc: 0.9953
#
# Epoch 00062: val_loss did not improve from 0.05055
# Epoch 63/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1326 - acc: 0.9659 - val_loss: 0.0799 - val_acc: 0.9869
#
# Epoch 00063: val_loss did not improve from 0.05055
# Epoch 64/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1178 - acc: 0.9687 - val_loss: 0.0548 - val_acc: 0.9963
#
# Epoch 00064: val_loss did not improve from 0.05055
# Epoch 65/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1237 - acc: 0.9696 - val_loss: 0.0468 - val_acc: 0.9984
#
# Epoch 00065: val_loss improved from 0.05055 to 0.04683, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 66/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1162 - acc: 0.9699 - val_loss: 0.0498 - val_acc: 0.9979
#
# Epoch 00066: val_loss did not improve from 0.04683
# Epoch 67/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1391 - acc: 0.9682 - val_loss: 0.0554 - val_acc: 0.9960
#
# Epoch 00067: val_loss did not improve from 0.04683
# Epoch 68/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1210 - acc: 0.9678 - val_loss: 0.0710 - val_acc: 0.9932
#
# Epoch 00068: val_loss did not improve from 0.04683
# Epoch 69/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1266 - acc: 0.9654 - val_loss: 0.0464 - val_acc: 0.9988
#
# Epoch 00069: val_loss improved from 0.04683 to 0.04637, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 70/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1196 - acc: 0.9687 - val_loss: 0.0533 - val_acc: 0.9965
#
# Epoch 00070: val_loss did not improve from 0.04637
# Epoch 71/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1247 - acc: 0.9671 - val_loss: 0.0462 - val_acc: 0.9979
#
# Epoch 00071: val_loss improved from 0.04637 to 0.04615, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 72/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.1241 - acc: 0.9673 - val_loss: 0.0459 - val_acc: 0.9979
#
# Epoch 00072: val_loss improved from 0.04615 to 0.04588, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 73/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1339 - acc: 0.9652 - val_loss: 0.0475 - val_acc: 0.9970
#
# Epoch 00073: val_loss did not improve from 0.04588
# Epoch 74/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1423 - acc: 0.9636 - val_loss: 0.0448 - val_acc: 0.9984
#
# Epoch 00074: val_loss improved from 0.04588 to 0.04477, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 75/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1133 - acc: 0.9694 - val_loss: 0.0559 - val_acc: 0.9963
#
# Epoch 00075: val_loss did not improve from 0.04477
# Epoch 76/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1170 - acc: 0.9694 - val_loss: 0.0612 - val_acc: 0.9949
#
# Epoch 00076: val_loss did not improve from 0.04477
# Epoch 77/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1207 - acc: 0.9701 - val_loss: 0.0452 - val_acc: 0.9981
#
# Epoch 00077: val_loss did not improve from 0.04477
# Epoch 78/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1175 - acc: 0.9706 - val_loss: 0.0447 - val_acc: 0.9977
#
# Epoch 00078: val_loss improved from 0.04477 to 0.04473, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 79/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1093 - acc: 0.9708 - val_loss: 0.0556 - val_acc: 0.9956
#
# Epoch 00079: val_loss did not improve from 0.04473
# Epoch 80/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1289 - acc: 0.9650 - val_loss: 0.0536 - val_acc: 0.9953
#
# Epoch 00080: val_loss did not improve from 0.04473
# Epoch 81/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1277 - acc: 0.9678 - val_loss: 0.0585 - val_acc: 0.9939
#
# Epoch 00081: val_loss did not improve from 0.04473
# Epoch 82/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1152 - acc: 0.9699 - val_loss: 0.0511 - val_acc: 0.9963
#
# Epoch 00082: val_loss did not improve from 0.04473
# Epoch 83/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.1152 - acc: 0.9715 - val_loss: 0.0580 - val_acc: 0.9956
#
# Epoch 00083: val_loss did not improve from 0.04473
# Epoch 84/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1151 - acc: 0.9694 - val_loss: 0.1991 - val_acc: 0.9650
#
# Epoch 00084: val_loss did not improve from 0.04473
# Epoch 85/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.1095 - acc: 0.9717 - val_loss: 0.0525 - val_acc: 0.9972
#
# Epoch 00085: val_loss did not improve from 0.04473
# Epoch 86/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1154 - acc: 0.9668 - val_loss: 0.0432 - val_acc: 0.9979
#
# Epoch 00086: val_loss improved from 0.04473 to 0.04318, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 87/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1159 - acc: 0.9671 - val_loss: 0.0443 - val_acc: 0.9974
#
# Epoch 00087: val_loss did not improve from 0.04318
# Epoch 88/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1192 - acc: 0.9715 - val_loss: 0.0701 - val_acc: 0.9932
#
# Epoch 00088: val_loss did not improve from 0.04318
# Epoch 89/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1057 - acc: 0.9717 - val_loss: 0.0468 - val_acc: 0.9965
#
# Epoch 00089: val_loss did not improve from 0.04318
# Epoch 90/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1148 - acc: 0.9687 - val_loss: 0.0501 - val_acc: 0.9967
#
# Epoch 00090: val_loss did not improve from 0.04318
# Epoch 91/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1296 - acc: 0.9668 - val_loss: 0.0441 - val_acc: 0.9977
#
# Epoch 00091: val_loss did not improve from 0.04318
# Epoch 92/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1063 - acc: 0.9724 - val_loss: 0.0473 - val_acc: 0.9972
#
# Epoch 00092: val_loss did not improve from 0.04318
# Epoch 93/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1040 - acc: 0.9748 - val_loss: 0.0524 - val_acc: 0.9944
#
# Epoch 00093: val_loss did not improve from 0.04318
# Epoch 94/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0957 - acc: 0.9773 - val_loss: 0.0988 - val_acc: 0.9886
#
# Epoch 00094: val_loss did not improve from 0.04318
# Epoch 95/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1016 - acc: 0.9773 - val_loss: 0.0459 - val_acc: 0.9970
#
# Epoch 00095: val_loss did not improve from 0.04318
# Epoch 96/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1047 - acc: 0.9741 - val_loss: 0.0400 - val_acc: 0.9988
#
# Epoch 00096: val_loss improved from 0.04318 to 0.03995, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 97/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1239 - acc: 0.9692 - val_loss: 0.0859 - val_acc: 0.9907
#
# Epoch 00097: val_loss did not improve from 0.03995
# Epoch 98/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1031 - acc: 0.9713 - val_loss: 0.0546 - val_acc: 0.9942
#
# Epoch 00098: val_loss did not improve from 0.03995
# Epoch 99/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1107 - acc: 0.9745 - val_loss: 0.0615 - val_acc: 0.9939
#
# Epoch 00099: val_loss did not improve from 0.03995
# Epoch 100/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1088 - acc: 0.9748 - val_loss: 0.0412 - val_acc: 0.9977
#
# Epoch 00100: val_loss did not improve from 0.03995
# Epoch 101/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1175 - acc: 0.9699 - val_loss: 0.0404 - val_acc: 0.9979
#
# Epoch 00101: val_loss did not improve from 0.03995
# Epoch 102/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1026 - acc: 0.9724 - val_loss: 0.0394 - val_acc: 0.9986
#
# Epoch 00102: val_loss improved from 0.03995 to 0.03943, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 103/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1077 - acc: 0.9699 - val_loss: 0.0382 - val_acc: 0.9986
#
# Epoch 00103: val_loss improved from 0.03943 to 0.03821, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 104/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1209 - acc: 0.9673 - val_loss: 0.0474 - val_acc: 0.9960
#
# Epoch 00104: val_loss did not improve from 0.03821
# Epoch 105/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1201 - acc: 0.9706 - val_loss: 0.0390 - val_acc: 0.9979
#
# Epoch 00105: val_loss did not improve from 0.03821
# Epoch 106/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1104 - acc: 0.9682 - val_loss: 0.0371 - val_acc: 0.9993
#
# Epoch 00106: val_loss improved from 0.03821 to 0.03708, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 107/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1309 - acc: 0.9657 - val_loss: 0.0464 - val_acc: 0.9970
#
# Epoch 00107: val_loss did not improve from 0.03708
# Epoch 108/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1019 - acc: 0.9773 - val_loss: 0.0496 - val_acc: 0.9965
#
# Epoch 00108: val_loss did not improve from 0.03708
# Epoch 109/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0980 - acc: 0.9755 - val_loss: 0.0420 - val_acc: 0.9963
#
# Epoch 00109: val_loss did not improve from 0.03708
# Epoch 110/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1009 - acc: 0.9759 - val_loss: 0.0421 - val_acc: 0.9977
#
# Epoch 00110: val_loss did not improve from 0.03708
# Epoch 111/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1112 - acc: 0.9706 - val_loss: 0.0388 - val_acc: 0.9981
#
# Epoch 00111: val_loss did not improve from 0.03708
# Epoch 112/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1043 - acc: 0.9722 - val_loss: 0.0399 - val_acc: 0.9977
#
# Epoch 00112: val_loss did not improve from 0.03708
# Epoch 113/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1182 - acc: 0.9729 - val_loss: 0.0559 - val_acc: 0.9958
#
# Epoch 00113: val_loss did not improve from 0.03708
# Epoch 114/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1082 - acc: 0.9708 - val_loss: 0.0553 - val_acc: 0.9946
#
# Epoch 00114: val_loss did not improve from 0.03708
# Epoch 115/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1113 - acc: 0.9682 - val_loss: 0.0408 - val_acc: 0.9981
#
# Epoch 00115: val_loss did not improve from 0.03708
# Epoch 116/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1094 - acc: 0.9736 - val_loss: 0.0436 - val_acc: 0.9970
#
# Epoch 00116: val_loss did not improve from 0.03708
# Epoch 117/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0980 - acc: 0.9734 - val_loss: 0.0460 - val_acc: 0.9956
#
# Epoch 00117: val_loss did not improve from 0.03708
# Epoch 118/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0972 - acc: 0.9748 - val_loss: 0.0442 - val_acc: 0.9974
#
# Epoch 00118: val_loss did not improve from 0.03708
# Epoch 119/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0989 - acc: 0.9764 - val_loss: 0.0490 - val_acc: 0.9956
#
# Epoch 00119: val_loss did not improve from 0.03708
# Epoch 120/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0928 - acc: 0.9759 - val_loss: 0.0413 - val_acc: 0.9984
#
# Epoch 00120: val_loss did not improve from 0.03708
# Epoch 121/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1062 - acc: 0.9748 - val_loss: 0.0497 - val_acc: 0.9958
#
# Epoch 00121: val_loss did not improve from 0.03708
# Epoch 122/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1009 - acc: 0.9776 - val_loss: 0.0613 - val_acc: 0.9932
#
# Epoch 00122: val_loss did not improve from 0.03708
# Epoch 123/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1045 - acc: 0.9722 - val_loss: 0.0349 - val_acc: 0.9988
#
# Epoch 00123: val_loss improved from 0.03708 to 0.03489, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 124/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0968 - acc: 0.9752 - val_loss: 0.0398 - val_acc: 0.9972
#
# Epoch 00124: val_loss did not improve from 0.03489
# Epoch 125/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1063 - acc: 0.9708 - val_loss: 0.0708 - val_acc: 0.9907
#
# Epoch 00125: val_loss did not improve from 0.03489
# Epoch 126/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1102 - acc: 0.9724 - val_loss: 0.0380 - val_acc: 0.9986
#
# Epoch 00126: val_loss did not improve from 0.03489
# Epoch 127/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0990 - acc: 0.9759 - val_loss: 0.0424 - val_acc: 0.9979
#
# Epoch 00127: val_loss did not improve from 0.03489
# Epoch 128/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1007 - acc: 0.9722 - val_loss: 0.0553 - val_acc: 0.9949
#
# Epoch 00128: val_loss did not improve from 0.03489
# Epoch 129/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.0996 - acc: 0.9748 - val_loss: 0.0349 - val_acc: 0.9988
#
# Epoch 00129: val_loss did not improve from 0.03489
# Epoch 130/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1016 - acc: 0.9776 - val_loss: 0.0375 - val_acc: 0.9977
#
# Epoch 00130: val_loss did not improve from 0.03489
# Epoch 131/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1269 - acc: 0.9699 - val_loss: 0.0511 - val_acc: 0.9949
#
# Epoch 00131: val_loss did not improve from 0.03489
# Epoch 132/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1069 - acc: 0.9722 - val_loss: 0.0432 - val_acc: 0.9965
#
# Epoch 00132: val_loss did not improve from 0.03489
# Epoch 133/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0942 - acc: 0.9722 - val_loss: 0.0407 - val_acc: 0.9977
#
# Epoch 00133: val_loss did not improve from 0.03489
# Epoch 134/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1244 - acc: 0.9713 - val_loss: 0.0387 - val_acc: 0.9981
#
# Epoch 00134: val_loss did not improve from 0.03489
# Epoch 135/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1135 - acc: 0.9715 - val_loss: 0.0437 - val_acc: 0.9974
#
# Epoch 00135: val_loss did not improve from 0.03489
# Epoch 136/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1045 - acc: 0.9748 - val_loss: 0.0407 - val_acc: 0.9974
#
# Epoch 00136: val_loss did not improve from 0.03489
# Epoch 137/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0921 - acc: 0.9750 - val_loss: 0.0374 - val_acc: 0.9986
#
# Epoch 00137: val_loss did not improve from 0.03489
# Epoch 138/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0886 - acc: 0.9780 - val_loss: 0.0701 - val_acc: 0.9939
#
# Epoch 00138: val_loss did not improve from 0.03489
# Epoch 139/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1006 - acc: 0.9738 - val_loss: 0.0494 - val_acc: 0.9946
#
# Epoch 00139: val_loss did not improve from 0.03489
# Epoch 140/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0972 - acc: 0.9738 - val_loss: 0.0482 - val_acc: 0.9958
#
# Epoch 00140: val_loss did not improve from 0.03489
# Epoch 141/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0950 - acc: 0.9769 - val_loss: 0.0410 - val_acc: 0.9972
#
# Epoch 00141: val_loss did not improve from 0.03489
# Epoch 142/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1084 - acc: 0.9720 - val_loss: 0.0353 - val_acc: 0.9984
#
# Epoch 00142: val_loss did not improve from 0.03489
# Epoch 143/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1286 - acc: 0.9673 - val_loss: 0.0811 - val_acc: 0.9918
#
# Epoch 00143: val_loss did not improve from 0.03489
# Epoch 144/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0925 - acc: 0.9776 - val_loss: 0.0577 - val_acc: 0.9939
#
# Epoch 00144: val_loss did not improve from 0.03489
# Epoch 145/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1044 - acc: 0.9689 - val_loss: 0.0623 - val_acc: 0.9935
#
# Epoch 00145: val_loss did not improve from 0.03489
# Epoch 146/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1012 - acc: 0.9708 - val_loss: 0.0443 - val_acc: 0.9965
#
# Epoch 00146: val_loss did not improve from 0.03489
# Epoch 147/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0872 - acc: 0.9766 - val_loss: 0.0361 - val_acc: 0.9979
#
# Epoch 00147: val_loss did not improve from 0.03489
# Epoch 148/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0810 - acc: 0.9808 - val_loss: 0.0464 - val_acc: 0.9953
#
# Epoch 00148: val_loss did not improve from 0.03489
# Epoch 149/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1231 - acc: 0.9696 - val_loss: 0.0415 - val_acc: 0.9974
#
# Epoch 00149: val_loss did not improve from 0.03489
# Epoch 150/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0955 - acc: 0.9769 - val_loss: 0.0404 - val_acc: 0.9970
#
# Epoch 00150: val_loss did not improve from 0.03489
# Epoch 151/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1072 - acc: 0.9724 - val_loss: 0.0388 - val_acc: 0.9977
#
# Epoch 00151: val_loss did not improve from 0.03489
# Epoch 152/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0878 - acc: 0.9750 - val_loss: 0.0441 - val_acc: 0.9951
#
# Epoch 00152: val_loss did not improve from 0.03489
# Epoch 153/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1001 - acc: 0.9743 - val_loss: 0.0411 - val_acc: 0.9970
#
# Epoch 00153: val_loss did not improve from 0.03489
# Epoch 154/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1034 - acc: 0.9743 - val_loss: 0.0424 - val_acc: 0.9970
#
# Epoch 00154: val_loss did not improve from 0.03489
# Epoch 155/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1008 - acc: 0.9773 - val_loss: 0.0363 - val_acc: 0.9979
#
# Epoch 00155: val_loss did not improve from 0.03489
# Epoch 156/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1014 - acc: 0.9757 - val_loss: 0.0632 - val_acc: 0.9930
#
# Epoch 00156: val_loss did not improve from 0.03489
# Epoch 157/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0984 - acc: 0.9748 - val_loss: 0.0368 - val_acc: 0.9979
#
# Epoch 00157: val_loss did not improve from 0.03489
# Epoch 158/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0980 - acc: 0.9755 - val_loss: 0.0339 - val_acc: 0.9977
#
# Epoch 00158: val_loss improved from 0.03489 to 0.03385, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 159/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0937 - acc: 0.9750 - val_loss: 0.0485 - val_acc: 0.9970
#
# Epoch 00159: val_loss did not improve from 0.03385
# Epoch 160/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0980 - acc: 0.9708 - val_loss: 0.0531 - val_acc: 0.9937
#
# Epoch 00160: val_loss did not improve from 0.03385
# Epoch 161/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0885 - acc: 0.9787 - val_loss: 0.0410 - val_acc: 0.9972
#
# Epoch 00161: val_loss did not improve from 0.03385
# Epoch 162/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0994 - acc: 0.9750 - val_loss: 0.0423 - val_acc: 0.9967
#
# Epoch 00162: val_loss did not improve from 0.03385
# Epoch 163/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1010 - acc: 0.9743 - val_loss: 0.0477 - val_acc: 0.9960
#
# Epoch 00163: val_loss did not improve from 0.03385
# Epoch 164/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0913 - acc: 0.9778 - val_loss: 0.0388 - val_acc: 0.9972
#
# Epoch 00164: val_loss did not improve from 0.03385
# Epoch 165/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0936 - acc: 0.9731 - val_loss: 0.0447 - val_acc: 0.9970
#
# Epoch 00165: val_loss did not improve from 0.03385
# Epoch 166/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0873 - acc: 0.9787 - val_loss: 0.0353 - val_acc: 0.9979
#
# Epoch 00166: val_loss did not improve from 0.03385
# Epoch 167/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1023 - acc: 0.9780 - val_loss: 0.0549 - val_acc: 0.9951
#
# Epoch 00167: val_loss did not improve from 0.03385
# Epoch 168/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1028 - acc: 0.9755 - val_loss: 0.0370 - val_acc: 0.9972
#
# Epoch 00168: val_loss did not improve from 0.03385
# Epoch 169/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1025 - acc: 0.9731 - val_loss: 0.0338 - val_acc: 0.9988
#
# Epoch 00169: val_loss improved from 0.03385 to 0.03384, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 170/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0938 - acc: 0.9738 - val_loss: 0.0408 - val_acc: 0.9965
#
# Epoch 00170: val_loss did not improve from 0.03384
# Epoch 171/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1032 - acc: 0.9729 - val_loss: 0.0633 - val_acc: 0.9930
#
# Epoch 00171: val_loss did not improve from 0.03384
# Epoch 172/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.1040 - acc: 0.9729 - val_loss: 0.0504 - val_acc: 0.9965
#
# Epoch 00172: val_loss did not improve from 0.03384
# Epoch 173/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0895 - acc: 0.9778 - val_loss: 0.0367 - val_acc: 0.9984
#
# Epoch 00173: val_loss did not improve from 0.03384
# Epoch 174/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.0891 - acc: 0.9787 - val_loss: 0.0356 - val_acc: 0.9984
#
# Epoch 00174: val_loss did not improve from 0.03384
# Epoch 175/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0947 - acc: 0.9752 - val_loss: 0.0404 - val_acc: 0.9970
#
# Epoch 00175: val_loss did not improve from 0.03384
# Epoch 176/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0941 - acc: 0.9743 - val_loss: 0.0670 - val_acc: 0.9930
#
# Epoch 00176: val_loss did not improve from 0.03384
# Epoch 177/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0884 - acc: 0.9771 - val_loss: 0.0537 - val_acc: 0.9960
#
# Epoch 00177: val_loss did not improve from 0.03384
# Epoch 178/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0998 - acc: 0.9771 - val_loss: 0.0448 - val_acc: 0.9965
#
# Epoch 00178: val_loss did not improve from 0.03384
# Epoch 179/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0957 - acc: 0.9787 - val_loss: 0.0518 - val_acc: 0.9937
#
# Epoch 00179: val_loss did not improve from 0.03384
# Epoch 180/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0901 - acc: 0.9766 - val_loss: 0.0471 - val_acc: 0.9963
#
# Epoch 00180: val_loss did not improve from 0.03384
# Epoch 181/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0959 - acc: 0.9790 - val_loss: 0.0520 - val_acc: 0.9944
#
# Epoch 00181: val_loss did not improve from 0.03384
# Epoch 182/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0854 - acc: 0.9755 - val_loss: 0.0406 - val_acc: 0.9974
#
# Epoch 00182: val_loss did not improve from 0.03384
# Epoch 183/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0979 - acc: 0.9738 - val_loss: 0.0554 - val_acc: 0.9965
#
# Epoch 00183: val_loss did not improve from 0.03384
# Epoch 184/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0876 - acc: 0.9778 - val_loss: 0.0347 - val_acc: 0.9981
#
# Epoch 00184: val_loss did not improve from 0.03384
# Epoch 185/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0851 - acc: 0.9783 - val_loss: 0.0383 - val_acc: 0.9974
#
# Epoch 00185: val_loss did not improve from 0.03384
# Epoch 186/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.0896 - acc: 0.9757 - val_loss: 0.0487 - val_acc: 0.9953
#
# Epoch 00186: val_loss did not improve from 0.03384
# Epoch 187/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0927 - acc: 0.9766 - val_loss: 0.0362 - val_acc: 0.9977
#
# Epoch 00187: val_loss did not improve from 0.03384
# Epoch 188/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0887 - acc: 0.9792 - val_loss: 0.0554 - val_acc: 0.9958
#
# Epoch 00188: val_loss did not improve from 0.03384
# Epoch 189/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0970 - acc: 0.9752 - val_loss: 0.0391 - val_acc: 0.9974
#
# Epoch 00189: val_loss did not improve from 0.03384
# Epoch 190/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0899 - acc: 0.9769 - val_loss: 0.0539 - val_acc: 0.9946
#
# Epoch 00190: val_loss did not improve from 0.03384
# Epoch 191/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0927 - acc: 0.9773 - val_loss: 0.0377 - val_acc: 0.9974
#
# Epoch 00191: val_loss did not improve from 0.03384
# Epoch 192/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0857 - acc: 0.9778 - val_loss: 0.0664 - val_acc: 0.9939
#
# Epoch 00192: val_loss did not improve from 0.03384
# Epoch 193/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0720 - acc: 0.9815 - val_loss: 0.0328 - val_acc: 0.9979
#
# Epoch 00193: val_loss improved from 0.03384 to 0.03277, saving model to ./drive/My Drive/Residual_HSI-Colab/SSRN/models/UP_mod_best_RES_3D_SS4_5_1.hdf5
# Epoch 194/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0978 - acc: 0.9771 - val_loss: 0.0368 - val_acc: 0.9977
#
# Epoch 00194: val_loss did not improve from 0.03277
# Epoch 195/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0995 - acc: 0.9762 - val_loss: 0.0705 - val_acc: 0.9928
#
# Epoch 00195: val_loss did not improve from 0.03277
# Epoch 196/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0820 - acc: 0.9804 - val_loss: 0.0408 - val_acc: 0.9965
#
# Epoch 00196: val_loss did not improve from 0.03277
# Epoch 197/200
# 4281/4281 [==============================] - 8s 2ms/step - loss: 0.0955 - acc: 0.9773 - val_loss: 0.0457 - val_acc: 0.9972
#
# Epoch 00197: val_loss did not improve from 0.03277
# Epoch 198/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0862 - acc: 0.9769 - val_loss: 0.0430 - val_acc: 0.9972
#
# Epoch 00198: val_loss did not improve from 0.03277
# Epoch 199/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.1004 - acc: 0.9748 - val_loss: 0.0405 - val_acc: 0.9970
#
# Epoch 00199: val_loss did not improve from 0.03277
# Epoch 200/200
# 4281/4281 [==============================] - 7s 2ms/step - loss: 0.0904 - acc: 0.9755 - val_loss: 0.0487 - val_acc: 0.9958
#
# Epoch 00200: val_loss did not improve from 0.03277
# 34214/34214 [==============================] - 10s 301us/step
# 3D RES_SS4 without BN Training Time:  1930.006079
# 3D RES_SS4 without BN Test time: 11.63906800000018
# 3D RES_SS4 without BN Test score: 0.03911219260262225
# 3D RES_SS4 without BN Test accuracy: 0.997047992050038
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# 3D RESNET_SS4 without BN training finished.
# # 1 Iteration
# Traceback (most recent call last):
#   File "./drive/My Drive/Residual_HSI-Colab/SSRN/SSRN_UP.py", line 225, in <module>
#     './drive/My Drive/Residual_HSI-Colab/records/UP_mod_train_SS_element_10.txt')
#   File "/content/drive/My Drive/Residual_HSI-Colab/SSRN/Utils/modelStatsRecord.py", line 48, in outputStats
#     newline='\n')
#   File "/usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py", line 1359, in savetxt
#     open(fname, 'wt').close()
# FileNotFoundError: [Errno 2] No such file or directory: './drive/My Drive/Residual_HSI-Colab/records/UP_mod_train_SS_element_10.txt'

# %%
#!python3 ./drive/My\ Drive/Residual_HSI-Colab/SSRN/IN_classification_maps.py
#!python3 ./drive/My\ Drive/Residual_HSI-Colab/SSRN/Visualization_mat2rgb.py

# %%
# !mv output.png ./drive/My\ Drive/Residual_HSI-Colab/SSRN
